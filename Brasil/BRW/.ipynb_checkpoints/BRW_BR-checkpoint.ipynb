# %% [markdown]
# # BRW Estimation

# %% [markdown]
# Replication code of the BRW shock by Bu, Wu, and Rogers (2021).

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from linearmodels.iv import IV2SLS
from bizdays import Calendar
from matplotlib.ticker import MaxNLocator

cal = Calendar.load("ANBIMA")
maturity = 2
year = 2020
month = 12
monthname = "Dec"
MAR2020 = 0

# %% [markdown]
# ## 1. Calculating the difference of the 2-year Treasury series (DGS2)

# %% [markdown]
# Load the data and rename columns

# %%
data = pd.read_excel(r"C:\Users\Alysson\Documents\GitHub\Monetary-Shocks\Brasil\BRW\DGS2.xls")
data.rename(columns={"observation_date": "date"}, inplace=True)
data.sort_values(by='date', inplace=True)
data.replace(0, method='ffill', inplace=True)

# %% [markdown]
# Convert date to datetime format and create additional date-related columns

# %%
data["date"] = pd.to_datetime(data["date"])
data["year"] = data["date"].dt.year
data["month"] = data["date"].dt.month
data["day"] = data["date"].dt.day
data["mdate"] = data["date"].dt.to_period("M")

# %% [markdown]
# Filter data for the specified period (up to September 2019 - Cut-off date used for the estimation in the research paper.)

# %%
data = data[data["mdate"] <= pd.Period("2023-07")]
data = data[data["mdate"] >= pd.Period("1994-01")]

# %% [markdown]
# Calculate the difference of the series (dgs_d)

# %%
data["dgs_d"] = data["DGS" + str(maturity)] - data["DGS" + str(maturity)].shift(1)

# %% [markdown]
# Set "mdate" as the index and convert it to a time series

# %%
data.set_index("mdate", inplace=True)
data.index = pd.to_datetime(data.index.to_timestamp())

# %% [markdown]
# Drop unnecessary columns

# %%
data.drop(columns=["year", "month", "day"], inplace=True)
data.head()
# Out:
#                  date     DGS2   dgs_d
# mdate
# 2000-04-01 2000-04-04  18.4837     NaN
# 2000-04-01 2000-04-05  18.7000  0.2163
# 2000-04-01 2000-04-06  18.8277  0.1277
# 2000-04-01 2000-04-07  18.6444 -0.1833
# 2000-04-01 2000-04-08  18.6444  0.0000

# %% [markdown]
# Save the resulting DataFrame to a new file

# %%
data.to_pickle("temp.pkl")

# %% [markdown]
# ## 2. Adding COPOM dates

# %% [markdown]
# Load the COPOM dates from the Excel file

# %%
copom_dates = pd.read_excel("C:/Users/Alysson/Documents/GitHub/Monetary-Shocks/Brasil/BRW/COPOMdate.xlsx")
copom_dates.rename(columns={"date": "COPOM_date"}, inplace=True)

# %% [markdown]
# Convert date to datetime format and create additional date-related columns

# %%
dias_uteis = 5
day2 = 2
iv2 = 0

copom_dates['COPOM_date'] = pd.to_datetime(copom_dates['COPOM_date'])
copom_dates = copom_dates[copom_dates['COPOM_date'] >= pd.Period("2001-01-01").to_timestamp()]
copom_dates['COPOM_date'] = cal.offset(copom_dates['COPOM_date'],1)
instrumento = pd.DataFrame({'COPOM_date': cal.offset(copom_dates['COPOM_date'],dias_uteis),'q':0})
instrumento_day2 = pd.DataFrame({'COPOM_date': cal.offset(copom_dates['COPOM_date'],day2),'q':2})
instrumento_iv2 = pd.DataFrame({'COPOM_date': cal.offset(copom_dates['COPOM_date'],day2),'q':3})

copom_dates = pd.concat([copom_dates, instrumento,instrumento_day2,instrumento_iv2])
copom_dates['COPOM_date'] = pd.to_datetime(copom_dates['COPOM_date'])
copom_dates["year"] = copom_dates["COPOM_date"].dt.year
copom_dates["month"] = copom_dates["COPOM_date"].dt.month
copom_dates["day"] = copom_dates["COPOM_date"].dt.day
copom_dates["mdate"] = copom_dates["COPOM_date"].dt.to_period("M")

# %% [markdown]
# Drop unnecessary columns

# %%
copom_dates.drop(columns=["year", "month", "day"], inplace=True)

# %% [markdown]
# Load the previous DataFrame "temp.dta"

# %%
temp_data = pd.read_pickle("temp.pkl")

# %%
copom_dates.sort_values("COPOM_date")
# Out:
#     COPOM_date  q    mdate
# 54  2001-01-18  1  2001-01
# 0   2001-01-22  2  2001-01
# 0   2001-01-22  3  2001-01
# 0   2001-01-25  0  2001-01
# 55  2001-02-15  1  2001-02
# ..         ... ..      ...
# 198 2023-03-30  0  2023-03
# 253 2023-05-04  1  2023-05
# 199 2023-05-08  3  2023-05
# 199 2023-05-08  2  2023-05
# 199 2023-05-11  0  2023-05
#
# [800 rows x 3 columns]

# %% [markdown]
# Merge the two DataFrames on the 'date' column

# %%
merged_data = pd.merge(temp_data, copom_dates, how="inner", left_on="date", right_on="COPOM_date")

# %% [markdown]
# Drop rows where 'q' is missing (denoted as NaN)

# %%
merged_data = merged_data.dropna(subset=["q"])

# %% [markdown]
# Replace missing values (NaN) in 'q' with 0

# %%
merged_data["q"].fillna(0, inplace=True)
merged_data.head()
# Out:
#         date     DGS2   dgs_d COPOM_date  q    mdate
# 0 2001-01-18  15.9121 -0.1365 2001-01-18  1  2001-01
# 1 2001-01-22  15.8581 -0.0069 2001-01-22  2  2001-01
# 2 2001-01-22  15.8581 -0.0069 2001-01-22  3  2001-01
# 3 2001-01-25  15.6341 -0.0425 2001-01-25  0  2001-01
# 4 2001-02-15  15.9326  0.1250 2001-02-15  1  2001-02

# %% [markdown]
# Save the merged DataFrame to a new file

# %%
merged_data.to_pickle("temp.pkl")

# %% [markdown]
# ## 3. Estimation

# %% [markdown]
# Load the data from "svensson_br.xlsx"

# %%
yield_data = pd.read_excel(r"C:\Users\Alysson\Documents\GitHub\Monetary-Shocks\Brasil\BRW\svensson_br.xlsx")

# %% [markdown]
# Convert 'date' column to datetime format and keeping only necessary columns

# %%
yield_data['date'] = pd.to_datetime(yield_data['Date'], format='%Y-%m-%d')
yield_data.sort_values(by='date', inplace=True)
yield_data.loc[:, 'SVENY01':'SVENY30'] = yield_data.loc[:, 'SVENY01':'SVENY30'].fillna(method='ffill')

# %%
yield_data['year'] = yield_data['date'].dt.year
yield_data['month'] = yield_data['date'].dt.month
yield_data['day'] = yield_data['date'].dt.day
yield_data['date'] = pd.to_datetime(yield_data[['year', 'month', 'day']])
yield_data['mdate'] = yield_data['date'].dt.to_period('M')
yield_data = yield_data[['date', 'mdate'] + [col for col in yield_data.columns if col.startswith('SVENY')]]
yield_data = yield_data[yield_data['mdate'] >= pd.Period('1994-01')]

# %%
yield_data.head()
# Out:
#         date    mdate    SVENY01    SVENY02    SVENY03    SVENY04    SVENY05  \
# 0 2006-01-02  2006-01  16.603599  16.069818  15.813602  15.678468  15.596889
# 1 2006-01-03  2006-01  16.594441  16.064808  15.800027  15.659489  15.574586
# 2 2006-01-04  2006-01  16.567391  15.906773  15.597463  15.460412  15.396983
# 3 2006-01-05  2006-01  16.564073  15.900342  15.579618  15.436914  15.374310
# 4 2006-01-06  2006-01  16.537489  15.886892  15.571989  15.437172  15.385606
#
#      SVENY06    SVENY07    SVENY08  ...    SVENY21    SVENY22    SVENY23  \
# 0  15.542471  15.503599  15.474444  ...  15.348109  15.344575  15.341349
# 1  15.517946  15.477487  15.447142  ...  15.315649  15.311971  15.308612
# 2  15.364394  15.345285  15.332609  ...  15.283329  15.281973  15.280736
# 3  15.346010  15.332288  15.324890  ...  15.304758  15.304254  15.303794
# 4  15.369317  15.366877  15.369324  ...  15.398403  15.399311  15.400141
#
#      SVENY24    SVENY25    SVENY26    SVENY27    SVENY28    SVENY29    SVENY30
# 0  15.338391  15.335670  15.333158  15.330832  15.328673  15.326662  15.324786
# 1  15.305534  15.302702  15.300088  15.297667  15.295419  15.293326  15.291373
# 2  15.279601  15.278557  15.277594  15.276701  15.275873  15.275102  15.274382
# 3  15.303372  15.302984  15.302626  15.302294  15.301986  15.301699  15.301432
# 4  15.400901  15.401600  15.402245  15.402843  15.403398  15.403915  15.404397
#
# [5 rows x 32 columns]

# %% [markdown]
# Create a list for all maturities of the treasuries

# %% [markdown]
# Calculate differences for each maturity

# %%
list_maturities = [str(i).zfill(2) for i in range(1, 31)]

for num in list_maturities:
    col_name = f'SVENY{num}'
    yield_data[f'{col_name}_d'] = yield_data[col_name].diff()
selected_columns = yield_data.iloc[:, -30:]

# %% [markdown]
# Create aligned_dgs_d column

# %%
data_complete = merged_data.merge(yield_data, on=['date','mdate'], how='inner')
data_complete.head()
# Out:
#         date     DGS2   dgs_d COPOM_date  q    mdate    SVENY01    SVENY02  \
# 0 2006-01-19  16.0114 -0.1546 2006-01-19  1  2006-01  16.009385  15.484445
# 1 2006-01-23  16.0114 -0.1546 2006-01-23  2  2006-01  16.017839  15.603053
# 2 2006-01-23  16.0114 -0.1546 2006-01-23  3  2006-01  16.017839  15.603053
# 3 2006-01-26  16.0298 -0.0181 2006-01-26  0  2006-01  16.025749  15.543076
# 4 2006-03-09  15.1785 -0.0968 2006-03-09  1  2006-03  15.205391  14.847149
#
#      SVENY03    SVENY04  ...  SVENY21_d  SVENY22_d  SVENY23_d  SVENY24_d  \
# 0  15.271040  15.173919  ...  -0.230086  -0.234513  -0.238557  -0.242266
# 1  15.414674  15.313681  ...   0.049312   0.047962   0.046729   0.045599
# 2  15.414674  15.313681  ...   0.049312   0.047962   0.046729   0.045599
# 3  15.320978  15.205124  ...  -0.132036  -0.132169  -0.132291  -0.132402
# 4  14.644118  14.517668  ...  -0.009660  -0.009165  -0.008713  -0.008298
#
#    SVENY25_d  SVENY26_d  SVENY27_d  SVENY28_d  SVENY29_d  SVENY30_d
# 0  -0.245679  -0.248830  -0.251747  -0.254456  -0.256979  -0.259333
# 1   0.044559   0.043599   0.042711   0.041885   0.041117   0.040400
# 2   0.044559   0.043599   0.042711   0.041885   0.041117   0.040400
# 3  -0.132504  -0.132599  -0.132686  -0.132767  -0.132843  -0.132913
# 4  -0.007917  -0.007565  -0.007240  -0.006937  -0.006655  -0.006392
#
# [5 rows x 66 columns]

# %% [markdown]
# ### Step 1 - 2SLS

# %%
### Creating IV

def step_1 (dataframe, q):
    mask_q0 = dataframe["q"] == 0
    mask_q1 = dataframe["q"] == q
    dataframe["const"] = 1
    dataframe["iv"] = dataframe[mask_q1]["dgs_d"]
    dataframe.loc[mask_q0, "iv"] = -1 * dataframe.loc[mask_q0, "dgs_d"]
    for num in list_maturities:
        col_name = f'SVENY{num}_d'
        model = IV2SLS(dependent=dataframe[col_name], endog=dataframe["dgs_d"], exog=dataframe[["const"]], instruments=dataframe["iv"])
        results = model.fit()
        dataframe[f"beta_hat{num}"]=results.params["dgs_d"]
        print(results)
    print(dataframe.head())
    return (dataframe)

# %% [markdown]
# ### Step 2 - Fama and MacBeth

# %%
def step_2 (dataframe):
    mask_q0 = dataframe["q"] == 0
    dataframe = dataframe.loc[~mask_q0]
    maxt = len(dataframe)

    aligned_dgs_d = []
    for num in range(maxt):
        sveny_values = dataframe.iloc[num, dataframe.columns.get_loc("SVENY01_d"):dataframe.columns.get_loc("SVENY30_d") + 1].values.astype(float)
        beta_values = dataframe.iloc[num, dataframe.columns.get_loc("beta_hat01"):dataframe.columns.get_loc("beta_hat30") + 1].values.astype(float)

        # Adicionando uma constante à matriz independente (para o termo constante na regressão)
        X = sm.add_constant(beta_values)

        # Realizando a regressão usando o OLS do StatsModels
        model = sm.OLS(sveny_values, X)
        results = model.fit()

        # Imprimindo os coeficientes beta estimados
        aligned_dgs_d.append(results.params[1:])

    dataframe["new_shock"] = aligned_dgs_d  
    dataframe["new_shock"] = dataframe["new_shock"].apply(lambda x: x[0])


    return (dataframe)

# %% [markdown]
# ### Renormalization

# %%
def renormalization (dataframe):
    renormalization = sm.OLS(dataframe["dgs_d"], dataframe["new_shock"])
    results_renormalization = renormalization.fit()
    beta_estimado = results_renormalization.params["new_shock"]
    dataframe["BRW_daily"]=dataframe["new_shock"]*beta_estimado 
    #print(results_renormalization.summary())
    BRW_regression = sm.OLS(dataframe["dgs_d"], dataframe["BRW_daily"])
    results_BRW_regression = BRW_regression.fit()
    print(results_BRW_regression.summary())
    return (dataframe)

# %%
data_brw = data_complete[data_complete["q"].isin([0, 1])].copy()

step_1(data_brw,1)
data_brw = step_2(data_brw)
renormalization(data_brw)
data_brw
# Out:
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY01_d   R-squared:                      0.5427
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.5410
# No. Observations:                 278   F-statistic:                    48.621
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.0000
# Time:                        14:01:56   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0018     0.0056    -0.3183     0.7503     -0.0127      0.0092
# dgs_d          1.2460     0.1787     6.9729     0.0000      0.8958      1.5962
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY02_d   R-squared:                      0.5595
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.5579
# No. Observations:                 278   F-statistic:                    36.242
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.0000
# Time:                        14:01:56   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0042     0.0060     0.6971     0.4857     -0.0075      0.0159
# dgs_d          0.9301     0.1545     6.0201     0.0000      0.6273      1.2329
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY03_d   R-squared:                      0.3857
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.3835
# No. Observations:                 278   F-statistic:                    6.5819
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.0103
# Time:                        14:01:56   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0077     0.0072     1.0710     0.2842     -0.0064      0.0218
# dgs_d          0.5808     0.2264     2.5655     0.0103      0.1371      1.0245
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY04_d   R-squared:                      0.2219
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.2191
# No. Observations:                 278   F-statistic:                    1.3253
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.2496
# Time:                        14:01:56   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0090     0.0082     1.0999     0.2714     -0.0071      0.0251
# dgs_d          0.3282     0.2851     1.1512     0.2496     -0.2306      0.8869
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY05_d   R-squared:                      0.0990
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.0957
# No. Observations:                 278   F-statistic:                    0.2090
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.6475
# Time:                        14:01:56   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0090     0.0090     1.0070     0.3139     -0.0085      0.0266
# dgs_d          0.1484     0.3245     0.4572     0.6475     -0.4877      0.7844
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY06_d   R-squared:                      0.0103
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.0067
# No. Observations:                 278   F-statistic:                    0.0020
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.9641
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0083     0.0095     0.8756     0.3812     -0.0103      0.0270
# dgs_d          0.0158     0.3511     0.0451     0.9641     -0.6723      0.7040
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY07_d   R-squared:                     -0.0541
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.0579
# No. Observations:                 278   F-statistic:                    0.0534
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.8172
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0073     0.0099     0.7380     0.4605     -0.0121      0.0268
# dgs_d         -0.0855     0.3698    -0.2312     0.8172     -0.8102      0.6392
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY08_d   R-squared:                     -0.1011
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1051
# No. Observations:                 278   F-statistic:                    0.1853
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.6668
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0062     0.0103     0.6059     0.5446     -0.0139      0.0263
# dgs_d         -0.1651     0.3835    -0.4305     0.6668     -0.9168      0.5866
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY09_d   R-squared:                     -0.1350
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1391
# No. Observations:                 278   F-statistic:                    0.3371
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.5615
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0051     0.0105     0.4831     0.6290     -0.0156      0.0258
# dgs_d         -0.2289     0.3943    -0.5806     0.5615     -1.0017      0.5439
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY10_d   R-squared:                     -0.1585
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1627
# No. Observations:                 278   F-statistic:                    0.4849
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.4862
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0040     0.0108     0.3704     0.7111     -0.0172      0.0252
# dgs_d         -0.2808     0.4032    -0.6963     0.4862     -1.0710      0.5095
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY11_d   R-squared:                     -0.1737
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1780
# No. Observations:                 278   F-statistic:                    0.6187
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.4315
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0030     0.0110     0.2675     0.7891     -0.0187      0.0246
# dgs_d         -0.3232     0.4109    -0.7866     0.4315     -1.1287      0.4822
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY12_d   R-squared:                     -0.1825
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1867
# No. Observations:                 278   F-statistic:                    0.7348
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.3913
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0020     0.0113     0.1739     0.8619     -0.0201      0.0240
# dgs_d         -0.3583     0.4180    -0.8572     0.3913     -1.1777      0.4610
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY13_d   R-squared:                     -0.1862
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1905
# No. Observations:                 278   F-statistic:                    0.8322
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.3616
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0010     0.0115     0.0890     0.9291     -0.0215      0.0235
# dgs_d         -0.3875     0.4248    -0.9122     0.3616     -1.2200      0.4450
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY14_d   R-squared:                     -0.1863
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1906
# No. Observations:                 278   F-statistic:                    0.9119
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.3396
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0001     0.0117     0.0123     0.9902     -0.0228      0.0231
# dgs_d         -0.4118     0.4312    -0.9549     0.3396     -1.2570      0.4334
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY15_d   R-squared:                     -0.1838
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1881
# No. Observations:                 278   F-statistic:                    0.9754
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.3233
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0007     0.0119    -0.0570     0.9546     -0.0241      0.0227
# dgs_d         -0.4322     0.4376    -0.9876     0.3233     -1.2899      0.4255
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY16_d   R-squared:                     -0.1796
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1838
# No. Observations:                 278   F-statistic:                    1.0247
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.3114
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0015     0.0121    -0.1194     0.9049     -0.0253      0.0224
# dgs_d         -0.4494     0.4439    -1.0123     0.3114     -1.3195      0.4207
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY17_d   R-squared:                     -0.1743
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1785
# No. Observations:                 278   F-statistic:                    1.0620
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.3028
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0022     0.0124    -0.1756     0.8606     -0.0264      0.0221
# dgs_d         -0.4639     0.4502    -1.0306     0.3028     -1.3463      0.4184
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY18_d   R-squared:                     -0.1683
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1726
# No. Observations:                 278   F-statistic:                    1.0893
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.2966
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0028     0.0126    -0.2262     0.8211     -0.0275      0.0218
# dgs_d         -0.4763     0.4563    -1.0437     0.2966     -1.3707      0.4181
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY19_d   R-squared:                     -0.1622
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1664
# No. Observations:                 278   F-statistic:                    1.1083
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.2925
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0035     0.0128    -0.2717     0.7859     -0.0285      0.0216
# dgs_d         -0.4868     0.4624    -1.0528     0.2925     -1.3932      0.4195
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY20_d   R-squared:                     -0.1560
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1602
# No. Observations:                 278   F-statistic:                    1.1206
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.2898
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0041     0.0130    -0.3127     0.7545     -0.0295      0.0214
# dgs_d         -0.4959     0.4684    -1.0586     0.2898     -1.4140      0.4222
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY21_d   R-squared:                     -0.1499
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1541
# No. Observations:                 278   F-statistic:                    1.1277
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.2883
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0046     0.0132    -0.3497     0.7266     -0.0305      0.0212
# dgs_d         -0.5037     0.4743    -1.0619     0.2883     -1.4332      0.4259
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY22_d   R-squared:                     -0.1441
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1482
# No. Observations:                 278   F-statistic:                    1.1306
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.2876
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0051     0.0134    -0.3830     0.7017     -0.0313      0.0211
# dgs_d         -0.5104     0.4800    -1.0633     0.2876     -1.4512      0.4304
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY23_d   R-squared:                     -0.1385
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1427
# No. Observations:                 278   F-statistic:                    1.1304
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.2877
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0056     0.0136    -0.4132     0.6794     -0.0322      0.0210
# dgs_d         -0.5163     0.4856    -1.0632     0.2877     -1.4680      0.4354
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY24_d   R-squared:                     -0.1333
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1374
# No. Observations:                 278   F-statistic:                    1.1277
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.2883
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0061     0.0137    -0.4406     0.6595     -0.0330      0.0209
# dgs_d         -0.5214     0.4910    -1.0619     0.2883     -1.4837      0.4409
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY25_d   R-squared:                     -0.1284
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1325
# No. Observations:                 278   F-statistic:                    1.1232
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.2892
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0065     0.0139    -0.4654     0.6416     -0.0337      0.0208
# dgs_d         -0.5259     0.4962    -1.0598     0.2892     -1.4984      0.4467
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY26_d   R-squared:                     -0.1239
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1280
# No. Observations:                 278   F-statistic:                    1.1173
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.2905
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0069     0.0141    -0.4880     0.6256     -0.0344      0.0207
# dgs_d         -0.5299     0.5013    -1.0570     0.2905     -1.5123      0.4526
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY27_d   R-squared:                     -0.1196
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1237
# No. Observations:                 278   F-statistic:                    1.1106
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.2920
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0072     0.0142    -0.5086     0.6111     -0.0351      0.0206
# dgs_d         -0.5334     0.5061    -1.0538     0.2920     -1.5254      0.4586
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY28_d   R-squared:                     -0.1157
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1198
# No. Observations:                 278   F-statistic:                    1.1032
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.2936
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0076     0.0144    -0.5274     0.5979     -0.0358      0.0206
# dgs_d         -0.5365     0.5108    -1.0503     0.2936     -1.5378      0.4647
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY29_d   R-squared:                     -0.1121
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1161
# No. Observations:                 278   F-statistic:                    1.0954
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.2953
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0079     0.0145    -0.5445     0.5861     -0.0364      0.0205
# dgs_d         -0.5394     0.5154    -1.0466     0.2953     -1.5495      0.4707
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY30_d   R-squared:                     -0.1087
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.1127
# No. Observations:                 278   F-statistic:                    1.0874
# Date:                Tue, Oct 10 2023   P-value (F-stat)                0.2970
# Time:                        14:01:57   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0082     0.0147    -0.5603     0.5753     -0.0369      0.0205
# dgs_d         -0.5420     0.5197    -1.0428     0.2970     -1.5606      0.4767
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#         date     DGS2   dgs_d COPOM_date  q    mdate    SVENY01    SVENY02  \
# 0 2006-01-19  16.0114 -0.1546 2006-01-19  1  2006-01  16.009385  15.484445
# 3 2006-01-26  16.0298 -0.0181 2006-01-26  0  2006-01  16.025749  15.543076
# 4 2006-03-09  15.1785 -0.0968 2006-03-09  1  2006-03  15.205391  14.847149
# 7 2006-03-16  14.9189  0.0371 2006-03-16  0  2006-03  14.920538  14.480900
# 8 2006-04-20  14.7318  0.0817 2006-04-20  1  2006-04  14.725141  14.768773
#
#      SVENY03    SVENY04  ...  beta_hat21  beta_hat22  beta_hat23  beta_hat24  \
# 0  15.271040  15.173919  ...   -0.503659   -0.510397   -0.516258    -0.52138
# 3  15.320978  15.205124  ...   -0.503659   -0.510397   -0.516258    -0.52138
# 4  14.644118  14.517668  ...   -0.503659   -0.510397   -0.516258    -0.52138
# 7  14.291530  14.179745  ...   -0.503659   -0.510397   -0.516258    -0.52138
# 8  14.903226  14.990924  ...   -0.503659   -0.510397   -0.516258    -0.52138
#
#    beta_hat25  beta_hat26  beta_hat27  beta_hat28  beta_hat29  beta_hat30
# 0   -0.525881   -0.529858   -0.533391   -0.536548   -0.539385   -0.541951
# 3   -0.525881   -0.529858   -0.533391   -0.536548   -0.539385   -0.541951
# 4   -0.525881   -0.529858   -0.533391   -0.536548   -0.539385   -0.541951
# 7   -0.525881   -0.529858   -0.533391   -0.536548   -0.539385   -0.541951
# 8   -0.525881   -0.529858   -0.533391   -0.536548   -0.539385   -0.541951
#
# [5 rows x 98 columns]
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  dgs_d   R-squared (uncentered):                   0.427
# Model:                            OLS   Adj. R-squared (uncentered):              0.423
# Method:                 Least Squares   F-statistic:                              103.0
# Date:                Tue, 10 Oct 2023   Prob (F-statistic):                    2.00e-18
# Time:                        14:01:57   Log-Likelihood:                          108.89
# No. Observations:                 139   AIC:                                     -215.8
# Df Residuals:                     138   BIC:                                     -212.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# BRW_daily      1.0000      0.099     10.150      0.000       0.805       1.195
# ==============================================================================
# Omnibus:                       19.701   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.260
# Skew:                           0.642   Prob(JB):                     1.34e-08
# Kurtosis:                       5.147   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\Alysson\AppData\Local\Temp\ipykernel_17840\3337792916.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe["new_shock"] = aligned_dgs_d
# C:\Users\Alysson\AppData\Local\Temp\ipykernel_17840\3337792916.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe["new_shock"] = dataframe["new_shock"].apply(lambda x: x[0])
#           date     DGS2   dgs_d COPOM_date  q    mdate    SVENY01    SVENY02  \
# 0   2006-01-19  16.0114 -0.1546 2006-01-19  1  2006-01  16.009385  15.484445
# 4   2006-03-09  15.1785 -0.0968 2006-03-09  1  2006-03  15.205391  14.847149
# 8   2006-04-20  14.7318  0.0817 2006-04-20  1  2006-04  14.725141  14.768773
# 12  2006-06-01  15.4108 -0.1473 2006-06-01  1  2006-06  15.483126  15.980536
# 16  2006-07-20  14.5070 -0.0238 2006-07-20  1  2006-07  14.551159  14.958297
# ..         ...      ...     ...        ... ..      ...        ...        ...
# 536 2022-10-27  13.1457 -0.0162 2022-10-27  1  2022-10  13.145766  12.092083
# 540 2022-12-08  13.7781 -0.0225 2022-12-08  1  2022-12  13.778129  13.217989
# 544 2023-02-02  13.5477  0.0871 2023-02-02  1  2023-02  13.547787  13.025719
# 548 2023-03-23  12.8195  0.1450 2023-03-23  1  2023-03  12.819528  12.148630
# 552 2023-05-04  12.6881  0.0000 2023-05-04  1  2023-05  12.625217  11.643865
#
#        SVENY03    SVENY04  ...  beta_hat23  beta_hat24  beta_hat25  \
# 0    15.271040  15.173919  ...   -0.516258    -0.52138   -0.525881
# 4    14.644118  14.517668  ...   -0.516258    -0.52138   -0.525881
# 8    14.903226  14.990924  ...   -0.516258    -0.52138   -0.525881
# 12   16.197760  16.342153  ...   -0.516258    -0.52138   -0.525881
# 16   15.236822  15.443164  ...   -0.516258    -0.52138   -0.525881
# ..         ...        ...  ...         ...         ...         ...
# 536  11.777311  11.765923  ...   -0.516258    -0.52138   -0.525881
# 540  12.926772  12.846204  ...   -0.516258    -0.52138   -0.525881
# 544  12.892275  12.911291  ...   -0.516258    -0.52138   -0.525881
# 548  12.286832  12.573268  ...   -0.516258    -0.52138   -0.525881
# 552  11.516161  11.641734  ...   -0.516258    -0.52138   -0.525881
#
#      beta_hat26  beta_hat27  beta_hat28  beta_hat29  beta_hat30  new_shock  \
# 0     -0.529858   -0.533391   -0.536548   -0.539385   -0.541951   0.109614
# 4     -0.529858   -0.533391   -0.536548   -0.539385   -0.541951  -0.051779
# 8     -0.529858   -0.533391   -0.536548   -0.539385   -0.541951   0.004412
# 12    -0.529858   -0.533391   -0.536548   -0.539385   -0.541951  -0.127731
# 16    -0.529858   -0.533391   -0.536548   -0.539385   -0.541951   0.007062
# ..          ...         ...         ...         ...         ...        ...
# 536   -0.529858   -0.533391   -0.536548   -0.539385   -0.541951   0.078181
# 540   -0.529858   -0.533391   -0.536548   -0.539385   -0.541951  -0.105204
# 544   -0.529858   -0.533391   -0.536548   -0.539385   -0.541951   0.153350
# 548   -0.529858   -0.533391   -0.536548   -0.539385   -0.541951  -0.031656
# 552   -0.529858   -0.533391   -0.536548   -0.539385   -0.541951  -0.069508
#
#      BRW_daily
# 0     0.073583
# 4    -0.034759
# 8     0.002962
# 12   -0.085745
# 16    0.004741
# ..         ...
# 536   0.052483
# 540  -0.070623
# 544   0.102943
# 548  -0.021251
# 552  -0.046660
#
# [139 rows x 100 columns]

# %%
# Definir a data de início e a data de término
start_date = pd.to_datetime("2006-01-01")
end_date = pd.to_datetime("2023-06-30")  # Especifique a data de término desejada

# Criar um intervalo de datas mensais até a data de término
date_range = pd.date_range(start=start_date, end=end_date, freq="M")

# Criar um DataFrame com a coluna de datas
data_monthly = pd.DataFrame({'mdate': date_range})

# Formatar as datas no estilo "1994-02"
data_monthly['mdate'] = data_monthly['mdate'].dt.strftime('%Y-%m')

columns = data_complete[['mdate', 'BRW_daily']]

columns['mdate'] = columns['mdate'].dt.strftime('%Y-%m')
data_monthly = data_monthly.merge(columns, on='mdate', how='left')
data_monthly['BRW_daily'].fillna(0, inplace=True)


# Imprimir as primeiras linhas do DataFrame
print(data_monthly)

# %%
# Converter valores do tipo Period para datetime
mdate_values = data_monthly["mdate"]
new_shock_values = data_monthly["BRW_daily"]

# Criar um gráfico de linha
plt.figure(figsize=(15, 6))
plt.plot(mdate_values, new_shock_values)
plt.title("BRW")
ax = plt.gca()
ax.xaxis.set_major_locator(MaxNLocator(nbins=20))
plt.xticks(rotation=45)
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
subset_data = data_monthly

# Especifique o nome do arquivo Excel de saída
output_file = "data_subset.xlsx"

# Salve o DataFrame no arquivo Excel
subset_data.to_excel(output_file, index=False)

# %%
# Seu código para criar os dados (mdate_values, new_shock_values) aqui

# Configuração do estilo do gráfico
plt.figure(figsize=(12, 6))
plt.plot(mdate_values, new_shock_values, color='darkblue', linewidth=2, label='BRW')
plt.title("Choque BRW - Brasil")
#plt.xlabel("Data")
#plt.ylabel("Valor do Choque")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(loc='upper left')

# Personalização do eixo x
ax = plt.gca()
ax.xaxis.set_major_locator(MaxNLocator(nbins=12))
plt.xticks(rotation=45)

# Adicionando grade horizontal
plt.axhline(0, color='gray', linestyle='--', linewidth=0.5)

# Ajustando margens e espaçamento
plt.tight_layout()

# Exibindo o gráfico
plt.show()
