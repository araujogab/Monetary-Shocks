# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np

# %%
# Leitura do Excel e conversão das variáveis na primeira linha para strings
df = pd.read_excel("Narrative_MP_Brazil_Dataset_with_Controls.xlsx", sheet_name="IPCA")
df.iloc[0] = df.iloc[0].astype(str)

# Coerção das colunas (exceto 'Data') para numéricas
df[df.columns[1:]] = df[df.columns[1:]].apply(pd.to_numeric, errors='coerce')

# Criando a variável de data
df['date'] = pd.to_datetime(df['Data'], format='%d-%m-%Y')

# Formatando a variável de data
df['date'] = df['date'].dt.to_period('M')

# Ordenando o DataFrame pela variável de data
df = df.sort_values('date')

# Configurando a série temporal
df = df.set_index('date')

# Descartando a variável 'Data'
df = df.drop(columns=['Data'])

# %%
df.head()
# Out:
#          Selic  Selic_d   ibcbr  ibcbrsa  ibcbrsa_log       pim     pimsa  \
# date
# 2006-01  17.25     0.00  108.55   113.36     4.730569  83.65213  90.63329
# 2006-02  17.25     0.00  107.80   113.64     4.733036  80.20779  91.37976
# 2006-03  16.50    -0.75  119.09   113.56     4.732331  92.39900  90.76299
# 2006-04  15.75    -0.75  112.61   114.24     4.738301  85.66672  91.32689
# 2006-05  15.75     0.00  117.19   115.65     4.750568  95.35205  91.89632
#
#          pimsa_log     pmcsa  pmcsa_log  ...     fgv_ind  fgv_ind_log  \
# date                                     ...
# 2006-01   4.506822  55.37375   4.014106  ...  120.771282     4.793899
# 2006-02   4.515024  54.72103   4.002248  ...  121.915021     4.803324
# 2006-03   4.508252  54.81225   4.003914  ...  121.594866     4.800695
# 2006-04   4.514445  55.45193   4.015517  ...  119.820464     4.785994
# 2006-05   4.520661  55.72637   4.020453  ...  120.083283     4.788186
#
#            fgv_serv  fgv_serv_log  logbrlem    logfci    ff4_tc    Choque  \
# date
# 2006-01  133.507340      4.894156  3.821372  4.608255 -0.177879  0.073583
# 2006-02  133.479233      4.893946  3.861958  4.609486  0.000000  0.000000
# 2006-03  133.933161      4.897341  3.851362  4.611407 -0.075017 -0.034759
# 2006-04  135.860118      4.911626  3.875185  4.609333  0.018302  0.002962
# 2006-05  134.599264      4.902302  3.809868  4.609002  0.000000  0.000000
#
#          Choque_pos  Choque_neg
# date
# 2006-01    0.073583    0.073583
# 2006-02    0.000000    0.000000
# 2006-03   -0.034759   -0.034759
# 2006-04    0.002962    0.002962
# 2006-05    0.000000    0.000000
#
# [5 rows x 24 columns]

# %%
# Renomeando colunas
df.rename(columns={'logbrlem': 'log_brlem', 'logfci': 'log_fci', 'ipca_log': 'log_ipca',
                   'pimsa_log': 'log_pimsa', 'ibcbrsa': 'log_ibcbrsa'}, inplace=True)


# Criando variáveis de mudanças percentuais mensais (MoM)
df['D_log_ipca'] = df['log_ipca'].diff()
df['D_log_pimsa'] = df['log_pimsa'].diff()
df['D_log_brlem'] = df['log_brlem'].diff()
df['D_log_fci'] = df['log_fci'].diff()

# Criando variáveis de mudanças percentuais anuais (YoY)
df['YoY_selic'] = df['Selic'] - df['Selic'].shift(12)
df['YoY_ipca'] = df['log_ipca'] - df['log_ipca'].shift(12)
df['YoY_pimsa'] = df['log_pimsa'] - df['log_pimsa'].shift(12)

# Criando variáveis de mudanças nas somas dos últimos seis meses (SoS)
df['SoS_selic'] = df['Selic'] - df['Selic'].shift(6)
df['SoS_ipca'] = df['log_ipca'] - df['log_ipca'].shift(6)
df['SoS_pimsa'] = df['log_pimsa'] - df['log_pimsa'].shift(6)

# Criando variáveis de mudanças nas somas dos últimos três meses (QoQ)
df['QoQ_selic'] = df['Selic'] - df['Selic'].shift(3)
df['QoQ_ipca'] = df['log_ipca'] - df['log_ipca'].shift(3)
df['QoQ_pimsa'] = df['log_pimsa'] - df['log_pimsa'].shift(3)

# %%
df["LP_lhs"] = df['log_ipca'].diff(1)

# %%
# Definindo o número de lags para suas variáveis de controle
controls_lag = 2

# Definindo o horizonte = 36
horizon = range(1,37)

# Adicionando variáveis defasadas ao DataFrame
list_var = ["log_ipca", "log_pimsa", "log_fci", "log_brlem"]


for month in horizon:
    df["LP_lhs"] = df['log_ipca'].diff(month)


    for lag in range(1, controls_lag + 1):
        for control in list_var:
            df[f"L{lag}.{control}"] = df[control].shift(lag)

    # Construindo a fórmula da regressão
    lagged_controls = [f"L{i}.{control}" for i in range(1, controls_lag + 1) for control in list_var]
    lagged_controls_str = ' + '.join([f"df['{control}']" for control in lagged_controls])

    formula = f"df['LP_lhs'] ~ df['Choque'] + {lagged_controls_str}"

    # Executando a regressão com erros padrão robustos
    model = sm.OLS.from_formula(formula, data=df).fit(cov_type='HAC', cov_kwds={'maxlags': nw_lag_truncation})

    # Imprimindo o resumo
    print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.421
# Model:                            OLS   Adj. R-squared:                  0.393
# Method:                 Least Squares   F-statistic:                     13.78
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           7.12e-17
# Time:                        14:38:29   Log-Likelihood:                 897.31
# No. Observations:                 196   AIC:                            -1775.
# Df Residuals:                     186   BIC:                            -1742.
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.2366      0.166      1.422      0.155      -0.089       0.563
# df['Choque']          -0.0010      0.003     -0.343      0.731      -0.007       0.005
# df['L1.log_ipca']      0.4831      0.077      6.274      0.000       0.332       0.634
# df['L1.log_pimsa']     0.0047      0.013      0.365      0.715      -0.021       0.030
# df['L1.log_fci']       0.0533      0.097      0.549      0.583      -0.137       0.244
# df['L1.log_brlem']     0.0031      0.007      0.458      0.647      -0.010       0.017
# df['L2.log_ipca']     -0.4827      0.077     -6.265      0.000      -0.634      -0.332
# df['L2.log_pimsa']     0.0085      0.013      0.660      0.509      -0.017       0.034
# df['L2.log_fci']      -0.1127      0.094     -1.205      0.228      -0.296       0.071
# df['L2.log_brlem']    -0.0093      0.007     -1.418      0.156      -0.022       0.004
# ==============================================================================
# Omnibus:                        7.441   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):               12.971
# Skew:                          -0.064   Prob(JB):                      0.00153
# Kurtosis:                       4.254   Cond. No.                     1.41e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.820
# Model:                            OLS   Adj. R-squared:                  0.811
# Method:                 Least Squares   F-statistic:                     79.35
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           6.73e-59
# Time:                        14:38:30   Log-Likelihood:                 897.31
# No. Observations:                 196   AIC:                            -1775.
# Df Residuals:                     186   BIC:                            -1742.
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.2366      0.166      1.422      0.155      -0.089       0.563
# df['Choque']          -0.0010      0.003     -0.343      0.731      -0.007       0.005
# df['L1.log_ipca']      1.4831      0.077     19.261      0.000       1.332       1.634
# df['L1.log_pimsa']     0.0047      0.013      0.365      0.715      -0.021       0.030
# df['L1.log_fci']       0.0533      0.097      0.549      0.583      -0.137       0.244
# df['L1.log_brlem']     0.0031      0.007      0.458      0.647      -0.010       0.017
# df['L2.log_ipca']     -1.4827      0.077    -19.245      0.000      -1.634      -1.332
# df['L2.log_pimsa']     0.0085      0.013      0.660      0.509      -0.017       0.034
# df['L2.log_fci']      -0.1127      0.094     -1.205      0.228      -0.296       0.071
# df['L2.log_brlem']    -0.0093      0.007     -1.418      0.156      -0.022       0.004
# ==============================================================================
# Omnibus:                        7.441   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):               12.971
# Skew:                          -0.064   Prob(JB):                      0.00153
# Kurtosis:                       4.254   Cond. No.                     1.41e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     91.45
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           2.75e-63
# Time:                        14:38:30   Log-Likelihood:                 833.71
# No. Observations:                 195   AIC:                            -1647.
# Df Residuals:                     185   BIC:                            -1615.
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.4624      0.190      2.430      0.015       0.089       0.835
# df['Choque']          -0.0038      0.004     -1.010      0.313      -0.011       0.004
# df['L1.log_ipca']      1.9697      0.127     15.566      0.000       1.722       2.218
# df['L1.log_pimsa']     0.0030      0.014      0.209      0.835      -0.025       0.031
# df['L1.log_fci']       0.0812      0.129      0.631      0.528      -0.171       0.333
# df['L1.log_brlem']     0.0103      0.009      1.089      0.276      -0.008       0.029
# df['L2.log_ipca']     -1.9675      0.127    -15.528      0.000      -2.216      -1.719
# df['L2.log_pimsa']     0.0243      0.015      1.673      0.094      -0.004       0.053
# df['L2.log_fci']      -0.2026      0.125     -1.624      0.104      -0.447       0.042
# df['L2.log_brlem']    -0.0207      0.009     -2.253      0.024      -0.039      -0.003
# ==============================================================================
# Omnibus:                        4.041   Durbin-Watson:                   2.412
# Prob(Omnibus):                  0.133   Jarque-Bera (JB):                5.113
# Skew:                          -0.005   Prob(JB):                       0.0776
# Kurtosis:                       3.793   Cond. No.                     1.41e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     56.36
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           3.16e-48
# Time:                        14:38:30   Log-Likelihood:                 749.53
# No. Observations:                 194   AIC:                            -1479.
# Df Residuals:                     184   BIC:                            -1446.
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.8502      0.355      2.397      0.017       0.155       1.545
# df['Choque']          -0.0031      0.005     -0.569      0.569      -0.014       0.008
# df['L1.log_ipca']      2.1811      0.182     11.992      0.000       1.825       2.538
# df['L1.log_pimsa']    -0.0002      0.019     -0.011      0.991      -0.037       0.036
# df['L1.log_fci']       0.1515      0.215      0.703      0.482      -0.271       0.573
# df['L1.log_brlem']     0.0129      0.015      0.858      0.391      -0.017       0.042
# df['L2.log_ipca']     -2.1766      0.182    -11.943      0.000      -2.534      -1.819
# df['L2.log_pimsa']     0.0441      0.020      2.214      0.027       0.005       0.083
# df['L2.log_fci']      -0.3728      0.206     -1.810      0.070      -0.777       0.031
# df['L2.log_brlem']    -0.0280      0.015     -1.930      0.054      -0.056       0.000
# ==============================================================================
# Omnibus:                        2.167   Durbin-Watson:                   1.641
# Prob(Omnibus):                  0.338   Jarque-Bera (JB):                2.044
# Skew:                          -0.006   Prob(JB):                        0.360
# Kurtosis:                       3.503   Cond. No.                     1.41e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.709
# Model:                            OLS   Adj. R-squared:                  0.695
# Method:                 Least Squares   F-statistic:                     39.99
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           1.01e-38
# Time:                        14:38:30   Log-Likelihood:                 697.72
# No. Observations:                 193   AIC:                            -1375.
# Df Residuals:                     183   BIC:                            -1343.
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.2417      0.491      2.531      0.011       0.280       2.203
# df['Choque']          -0.0046      0.007     -0.688      0.492      -0.018       0.009
# df['L1.log_ipca']      2.3365      0.225     10.368      0.000       1.895       2.778
# df['L1.log_pimsa']    -0.0115      0.026     -0.447      0.655      -0.062       0.039
# df['L1.log_fci']       0.1670      0.295      0.566      0.571      -0.411       0.745
# df['L1.log_brlem']     0.0250      0.018      1.367      0.172      -0.011       0.061
# df['L2.log_ipca']     -2.3295      0.226    -10.323      0.000      -2.772      -1.887
# df['L2.log_pimsa']     0.0690      0.026      2.631      0.009       0.018       0.120
# df['L2.log_fci']      -0.4879      0.285     -1.714      0.087      -1.046       0.070
# df['L2.log_brlem']    -0.0432      0.017     -2.483      0.013      -0.077      -0.009
# ==============================================================================
# Omnibus:                        2.493   Durbin-Watson:                   1.103
# Prob(Omnibus):                  0.287   Jarque-Bera (JB):                2.464
# Skew:                          -0.049   Prob(JB):                        0.292
# Kurtosis:                       3.545   Cond. No.                     1.41e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.653
# Model:                            OLS   Adj. R-squared:                  0.636
# Method:                 Least Squares   F-statistic:                     32.64
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           1.35e-33
# Time:                        14:38:30   Log-Likelihood:                 653.57
# No. Observations:                 192   AIC:                            -1287.
# Df Residuals:                     182   BIC:                            -1255.
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.8367      0.618      2.970      0.003       0.625       3.049
# df['Choque']          -0.0014      0.008     -0.169      0.866      -0.017       0.015
# df['L1.log_ipca']      2.3798      0.262      9.094      0.000       1.867       2.893
# df['L1.log_pimsa']    -0.0312      0.029     -1.084      0.278      -0.088       0.025
# df['L1.log_fci']       0.0534      0.356      0.150      0.881      -0.645       0.751
# df['L1.log_brlem']     0.0433      0.021      2.065      0.039       0.002       0.084
# df['L2.log_ipca']     -2.3699      0.262     -9.055      0.000      -2.883      -1.857
# df['L2.log_pimsa']     0.0936      0.027      3.422      0.001       0.040       0.147
# df['L2.log_fci']      -0.5135      0.344     -1.491      0.136      -1.189       0.162
# df['L2.log_brlem']    -0.0604      0.019     -3.140      0.002      -0.098      -0.023
# ==============================================================================
# Omnibus:                        0.701   Durbin-Watson:                   0.844
# Prob(Omnibus):                  0.704   Jarque-Bera (JB):                0.410
# Skew:                           0.073   Prob(JB):                        0.815
# Kurtosis:                       3.173   Cond. No.                     1.40e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.595
# Model:                            OLS   Adj. R-squared:                  0.575
# Method:                 Least Squares   F-statistic:                     25.77
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           3.46e-28
# Time:                        14:38:30   Log-Likelihood:                 616.14
# No. Observations:                 191   AIC:                            -1212.
# Df Residuals:                     181   BIC:                            -1180.
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.6121      0.755      3.461      0.001       1.133       4.091
# df['Choque']          -0.0007      0.009     -0.077      0.938      -0.019       0.017
# df['L1.log_ipca']      2.3556      0.292      8.066      0.000       1.783       2.928
# df['L1.log_pimsa']    -0.0370      0.034     -1.072      0.284      -0.105       0.031
# df['L1.log_fci']       0.0054      0.406      0.013      0.989      -0.791       0.801
# df['L1.log_brlem']     0.0530      0.026      2.015      0.044       0.001       0.105
# df['L2.log_ipca']     -2.3423      0.292     -8.029      0.000      -2.914      -1.770
# df['L2.log_pimsa']     0.1000      0.033      3.042      0.002       0.036       0.164
# df['L2.log_fci']      -0.6426      0.397     -1.620      0.105      -1.420       0.135
# df['L2.log_brlem']    -0.0665      0.024     -2.773      0.006      -0.114      -0.020
# ==============================================================================
# Omnibus:                        0.294   Durbin-Watson:                   0.652
# Prob(Omnibus):                  0.863   Jarque-Bera (JB):                0.237
# Skew:                           0.086   Prob(JB):                        0.888
# Kurtosis:                       2.987   Cond. No.                     1.40e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.549
# Model:                            OLS   Adj. R-squared:                  0.527
# Method:                 Least Squares   F-statistic:                     20.74
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           9.78e-24
# Time:                        14:38:30   Log-Likelihood:                 586.78
# No. Observations:                 190   AIC:                            -1154.
# Df Residuals:                     180   BIC:                            -1121.
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              3.4821      0.870      4.002      0.000       1.777       5.187
# df['Choque']           0.0031      0.010      0.299      0.765      -0.017       0.023
# df['L1.log_ipca']      2.2992      0.322      7.151      0.000       1.669       2.929
# df['L1.log_pimsa']    -0.0336      0.039     -0.870      0.384      -0.109       0.042
# df['L1.log_fci']      -0.1151      0.437     -0.263      0.792      -0.972       0.741
# df['L1.log_brlem']     0.0620      0.031      1.981      0.048       0.001       0.123
# df['L2.log_ipca']     -2.2827      0.321     -7.112      0.000      -2.912      -1.654
# df['L2.log_pimsa']     0.0933      0.035      2.655      0.008       0.024       0.162
# df['L2.log_fci']      -0.7163      0.424     -1.688      0.091      -1.548       0.115
# df['L2.log_brlem']    -0.0707      0.029     -2.459      0.014      -0.127      -0.014
# ==============================================================================
# Omnibus:                        0.957   Durbin-Watson:                   0.510
# Prob(Omnibus):                  0.620   Jarque-Bera (JB):                0.826
# Skew:                           0.161   Prob(JB):                        0.662
# Kurtosis:                       3.014   Cond. No.                     1.40e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.519
# Model:                            OLS   Adj. R-squared:                  0.495
# Method:                 Least Squares   F-statistic:                     16.97
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           4.57e-20
# Time:                        14:38:30   Log-Likelihood:                 563.65
# No. Observations:                 189   AIC:                            -1107.
# Df Residuals:                     179   BIC:                            -1075.
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              4.3349      0.983      4.409      0.000       2.408       6.262
# df['Choque']           0.0052      0.011      0.457      0.648      -0.017       0.027
# df['L1.log_ipca']      2.2670      0.363      6.243      0.000       1.555       2.979
# df['L1.log_pimsa']    -0.0264      0.041     -0.638      0.524      -0.107       0.055
# df['L1.log_fci']      -0.3064      0.479     -0.640      0.522      -1.244       0.632
# df['L1.log_brlem']     0.0688      0.035      1.937      0.053      -0.001       0.138
# df['L2.log_ipca']     -2.2475      0.362     -6.200      0.000      -2.958      -1.537
# df['L2.log_pimsa']     0.0820      0.036      2.272      0.023       0.011       0.153
# df['L2.log_fci']      -0.7149      0.458     -1.559      0.119      -1.613       0.184
# df['L2.log_brlem']    -0.0721      0.033     -2.204      0.028      -0.136      -0.008
# ==============================================================================
# Omnibus:                        2.614   Durbin-Watson:                   0.429
# Prob(Omnibus):                  0.271   Jarque-Bera (JB):                2.464
# Skew:                           0.280   Prob(JB):                        0.292
# Kurtosis:                       2.996   Cond. No.                     1.39e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.39e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.486
# Method:                 Least Squares   F-statistic:                     16.19
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           3.03e-19
# Time:                        14:38:30   Log-Likelihood:                 546.18
# No. Observations:                 188   AIC:                            -1072.
# Df Residuals:                     178   BIC:                            -1040.
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              5.0819      1.087      4.676      0.000       2.952       7.212
# df['Choque']           0.0059      0.013      0.468      0.640      -0.019       0.030
# df['L1.log_ipca']      2.3473      0.384      6.106      0.000       1.594       3.101
# df['L1.log_pimsa']    -0.0288      0.045     -0.637      0.524      -0.117       0.060
# df['L1.log_fci']      -0.4752      0.541     -0.878      0.380      -1.536       0.586
# df['L1.log_brlem']     0.0801      0.038      2.096      0.036       0.005       0.155
# df['L2.log_ipca']     -2.3253      0.384     -6.055      0.000      -3.078      -1.573
# df['L2.log_pimsa']     0.0775      0.040      1.949      0.051      -0.000       0.155
# df['L2.log_fci']      -0.7106      0.514     -1.383      0.167      -1.718       0.297
# df['L2.log_brlem']    -0.0769      0.036     -2.146      0.032      -0.147      -0.007
# ==============================================================================
# Omnibus:                        4.027   Durbin-Watson:                   0.397
# Prob(Omnibus):                  0.134   Jarque-Bera (JB):                3.971
# Skew:                           0.355   Prob(JB):                        0.137
# Kurtosis:                       2.943   Cond. No.                     1.39e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.39e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.515
# Model:                            OLS   Adj. R-squared:                  0.491
# Method:                 Least Squares   F-statistic:                     16.01
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           5.00e-19
# Time:                        14:38:30   Log-Likelihood:                 532.39
# No. Observations:                 187   AIC:                            -1045.
# Df Residuals:                     177   BIC:                            -1012.
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              5.7104      1.175      4.860      0.000       3.408       8.013
# df['Choque']           0.0075      0.013      0.560      0.576      -0.019       0.034
# df['L1.log_ipca']      2.6039      0.410      6.348      0.000       1.800       3.408
# df['L1.log_pimsa']    -0.0388      0.051     -0.761      0.447      -0.139       0.061
# df['L1.log_fci']      -0.5520      0.599     -0.922      0.357      -1.725       0.622
# df['L1.log_brlem']     0.0858      0.040      2.126      0.033       0.007       0.165
# df['L2.log_ipca']     -2.5796      0.410     -6.288      0.000      -3.384      -1.776
# df['L2.log_pimsa']     0.0747      0.047      1.582      0.114      -0.018       0.167
# df['L2.log_fci']      -0.7684      0.572     -1.342      0.180      -1.890       0.354
# df['L2.log_brlem']    -0.0736      0.038     -1.917      0.055      -0.149       0.002
# ==============================================================================
# Omnibus:                        5.687   Durbin-Watson:                   0.386
# Prob(Omnibus):                  0.058   Jarque-Bera (JB):                5.804
# Skew:                           0.427   Prob(JB):                       0.0549
# Kurtosis:                       2.875   Cond. No.                     1.39e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.39e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.521
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     15.81
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           8.51e-19
# Time:                        14:38:30   Log-Likelihood:                 519.36
# No. Observations:                 186   AIC:                            -1019.
# Df Residuals:                     176   BIC:                            -986.5
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              6.2176      1.241      5.010      0.000       3.785       8.650
# df['Choque']           0.0031      0.015      0.211      0.833      -0.026       0.032
# df['L1.log_ipca']      2.9376      0.458      6.407      0.000       2.039       3.836
# df['L1.log_pimsa']    -0.0442      0.059     -0.754      0.451      -0.159       0.071
# df['L1.log_fci']      -0.5669      0.654     -0.866      0.386      -1.849       0.715
# df['L1.log_brlem']     0.0862      0.041      2.083      0.037       0.005       0.167
# df['L2.log_ipca']     -2.9107      0.459     -6.345      0.000      -3.810      -2.012
# df['L2.log_pimsa']     0.0677      0.056      1.211      0.226      -0.042       0.177
# df['L2.log_fci']      -0.8637      0.630     -1.370      0.171      -2.099       0.372
# df['L2.log_brlem']    -0.0643      0.040     -1.621      0.105      -0.142       0.013
# ==============================================================================
# Omnibus:                        5.910   Durbin-Watson:                   0.393
# Prob(Omnibus):                  0.052   Jarque-Bera (JB):                6.038
# Skew:                           0.437   Prob(JB):                       0.0488
# Kurtosis:                       2.881   Cond. No.                     1.38e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.38e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.526
# Model:                            OLS   Adj. R-squared:                  0.502
# Method:                 Least Squares   F-statistic:                     16.08
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           4.83e-19
# Time:                        14:38:30   Log-Likelihood:                 507.03
# No. Observations:                 185   AIC:                            -994.1
# Df Residuals:                     175   BIC:                            -961.8
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              6.6122      1.297      5.099      0.000       4.070       9.154
# df['Choque']           0.0002      0.017      0.010      0.992      -0.032       0.033
# df['L1.log_ipca']      3.2787      0.500      6.562      0.000       2.299       4.258
# df['L1.log_pimsa']    -0.0531      0.064     -0.826      0.409      -0.179       0.073
# df['L1.log_fci']      -0.5132      0.727     -0.706      0.480      -1.938       0.912
# df['L1.log_brlem']     0.0881      0.043      2.027      0.043       0.003       0.173
# df['L2.log_ipca']     -3.2498      0.500     -6.500      0.000      -4.230      -2.270
# df['L2.log_pimsa']     0.0640      0.062      1.037      0.300      -0.057       0.185
# df['L2.log_fci']      -1.0010      0.705     -1.419      0.156      -2.383       0.381
# df['L2.log_brlem']    -0.0574      0.041     -1.396      0.163      -0.138       0.023
# ==============================================================================
# Omnibus:                        4.318   Durbin-Watson:                   0.431
# Prob(Omnibus):                  0.115   Jarque-Bera (JB):                4.326
# Skew:                           0.371   Prob(JB):                        0.115
# Kurtosis:                       2.901   Cond. No.                     1.38e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.38e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.534
# Model:                            OLS   Adj. R-squared:                  0.510
# Method:                 Least Squares   F-statistic:                     17.13
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           4.59e-20
# Time:                        14:38:30   Log-Likelihood:                 495.94
# No. Observations:                 184   AIC:                            -971.9
# Df Residuals:                     174   BIC:                            -939.7
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              6.8823      1.349      5.100      0.000       4.238       9.527
# df['Choque']          -0.0002      0.016     -0.014      0.989      -0.032       0.032
# df['L1.log_ipca']      3.6212      0.526      6.883      0.000       2.590       4.652
# df['L1.log_pimsa']    -0.0836      0.068     -1.232      0.218      -0.217       0.049
# df['L1.log_fci']      -0.3141      0.807     -0.389      0.697      -1.895       1.267
# df['L1.log_brlem']     0.1052      0.046      2.310      0.021       0.016       0.195
# df['L2.log_ipca']     -3.5897      0.526     -6.819      0.000      -4.621      -2.558
# df['L2.log_pimsa']     0.0798      0.067      1.195      0.232      -0.051       0.211
# df['L2.log_fci']      -1.2574      0.786     -1.601      0.109      -2.797       0.282
# df['L2.log_brlem']    -0.0638      0.043     -1.492      0.136      -0.148       0.020
# ==============================================================================
# Omnibus:                        3.140   Durbin-Watson:                   0.432
# Prob(Omnibus):                  0.208   Jarque-Bera (JB):                2.965
# Skew:                           0.311   Prob(JB):                        0.227
# Kurtosis:                       3.011   Cond. No.                     1.38e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.38e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.521
# Model:                            OLS   Adj. R-squared:                  0.496
# Method:                 Least Squares   F-statistic:                     16.97
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           7.05e-20
# Time:                        14:38:30   Log-Likelihood:                 482.10
# No. Observations:                 183   AIC:                            -944.2
# Df Residuals:                     173   BIC:                            -912.1
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              7.0677      1.435      4.926      0.000       4.255       9.880
# df['Choque']          -0.0046      0.017     -0.273      0.785      -0.037       0.028
# df['L1.log_ipca']      3.8486      0.560      6.868      0.000       2.750       4.947
# df['L1.log_pimsa']    -0.1018      0.071     -1.435      0.151      -0.241       0.037
# df['L1.log_fci']      -0.0071      0.887     -0.008      0.994      -1.746       1.732
# df['L1.log_brlem']     0.1126      0.049      2.311      0.021       0.017       0.208
# df['L2.log_ipca']     -3.8136      0.561     -6.802      0.000      -4.912      -2.715
# df['L2.log_pimsa']     0.0845      0.071      1.197      0.231      -0.054       0.223
# df['L2.log_fci']      -1.6059      0.863     -1.861      0.063      -3.297       0.086
# df['L2.log_brlem']    -0.0602      0.045     -1.327      0.185      -0.149       0.029
# ==============================================================================
# Omnibus:                        1.772   Durbin-Watson:                   0.458
# Prob(Omnibus):                  0.412   Jarque-Bera (JB):                1.501
# Skew:                           0.217   Prob(JB):                        0.472
# Kurtosis:                       3.093   Cond. No.                     1.38e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.38e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.502
# Model:                            OLS   Adj. R-squared:                  0.476
# Method:                 Least Squares   F-statistic:                     15.85
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           1.02e-18
# Time:                        14:38:30   Log-Likelihood:                 467.82
# No. Observations:                 182   AIC:                            -915.6
# Df Residuals:                     172   BIC:                            -883.6
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              7.1893      1.544      4.656      0.000       4.163      10.215
# df['Choque']          -0.0049      0.018     -0.273      0.785      -0.040       0.030
# df['L1.log_ipca']      4.0173      0.592      6.791      0.000       2.858       5.177
# df['L1.log_pimsa']    -0.1161      0.075     -1.557      0.119      -0.262       0.030
# df['L1.log_fci']       0.2043      0.956      0.214      0.831      -1.669       2.078
# df['L1.log_brlem']     0.1290      0.052      2.491      0.013       0.028       0.230
# df['L2.log_ipca']     -3.9781      0.592     -6.720      0.000      -5.138      -2.818
# df['L2.log_pimsa']     0.0834      0.073      1.137      0.255      -0.060       0.227
# df['L2.log_fci']      -1.8459      0.926     -1.993      0.046      -3.661      -0.031
# df['L2.log_brlem']    -0.0639      0.049     -1.316      0.188      -0.159       0.031
# ==============================================================================
# Omnibus:                        1.949   Durbin-Watson:                   0.462
# Prob(Omnibus):                  0.377   Jarque-Bera (JB):                1.636
# Skew:                           0.224   Prob(JB):                        0.441
# Kurtosis:                       3.124   Cond. No.                     1.37e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.483
# Model:                            OLS   Adj. R-squared:                  0.455
# Method:                 Least Squares   F-statistic:                     15.22
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           4.75e-18
# Time:                        14:38:30   Log-Likelihood:                 454.92
# No. Observations:                 181   AIC:                            -889.8
# Df Residuals:                     171   BIC:                            -857.8
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              7.1863      1.646      4.365      0.000       3.959      10.413
# df['Choque']          -0.0028      0.019     -0.146      0.884      -0.040       0.035
# df['L1.log_ipca']      4.1698      0.617      6.753      0.000       2.960       5.380
# df['L1.log_pimsa']    -0.1266      0.076     -1.664      0.096      -0.276       0.023
# df['L1.log_fci']       0.4261      0.995      0.428      0.669      -1.525       2.377
# df['L1.log_brlem']     0.1468      0.056      2.611      0.009       0.037       0.257
# df['L2.log_ipca']     -4.1249      0.618     -6.675      0.000      -5.336      -2.914
# df['L2.log_pimsa']     0.0787      0.074      1.070      0.285      -0.066       0.223
# df['L2.log_fci']      -2.0738      0.962     -2.155      0.031      -3.960      -0.188
# df['L2.log_brlem']    -0.0671      0.053     -1.277      0.202      -0.170       0.036
# ==============================================================================
# Omnibus:                        2.425   Durbin-Watson:                   0.430
# Prob(Omnibus):                  0.298   Jarque-Bera (JB):                2.036
# Skew:                           0.242   Prob(JB):                        0.361
# Kurtosis:                       3.191   Cond. No.                     1.37e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.450
# Model:                            OLS   Adj. R-squared:                  0.421
# Method:                 Least Squares   F-statistic:                     13.16
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           7.68e-16
# Time:                        14:38:30   Log-Likelihood:                 441.19
# No. Observations:                 180   AIC:                            -862.4
# Df Residuals:                     170   BIC:                            -830.5
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              7.0201      1.750      4.012      0.000       3.591      10.449
# df['Choque']          -0.0026      0.020     -0.131      0.896      -0.042       0.037
# df['L1.log_ipca']      4.1853      0.653      6.405      0.000       2.905       5.466
# ...
# Time:                        14:38:31   Log-Likelihood:                 350.60
# No. Observations:                 167   AIC:                            -681.2
# Df Residuals:                     157   BIC:                            -650.0
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.0923      1.928      1.085      0.278      -1.687       5.872
# df['Choque']          -0.0009      0.025     -0.034      0.973      -0.051       0.049
# df['L1.log_ipca']      4.6291      0.974      4.751      0.000       2.720       6.539
# df['L1.log_pimsa']    -0.1698      0.100     -1.701      0.089      -0.366       0.026
# df['L1.log_fci']       0.6910      1.379      0.501      0.616      -2.011       3.393
# df['L1.log_brlem']     0.1798      0.078      2.300      0.021       0.027       0.333
# df['L2.log_ipca']     -4.5486      0.977     -4.655      0.000      -6.464      -2.634
# df['L2.log_pimsa']     0.0341      0.094      0.364      0.716      -0.150       0.218
# df['L2.log_fci']      -1.2823      1.341     -0.956      0.339      -3.911       1.346
# df['L2.log_brlem']     0.0018      0.074      0.024      0.981      -0.144       0.148
# ==============================================================================
# Omnibus:                        0.717   Durbin-Watson:                   0.233
# Prob(Omnibus):                  0.699   Jarque-Bera (JB):                0.771
# Skew:                           0.153   Prob(JB):                        0.680
# Kurtosis:                       2.871   Cond. No.                     1.34e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.34e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.248
# Model:                            OLS   Adj. R-squared:                  0.204
# Method:                 Least Squares   F-statistic:                     6.399
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           1.04e-07
# Time:                        14:38:31   Log-Likelihood:                 345.04
# No. Observations:                 166   AIC:                            -670.1
# Df Residuals:                     156   BIC:                            -639.0
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.9072      1.976      0.965      0.334      -1.965       5.779
# df['Choque']           0.0003      0.025      0.013      0.990      -0.048       0.049
# df['L1.log_ipca']      4.4726      0.988      4.527      0.000       2.536       6.409
# df['L1.log_pimsa']    -0.1601      0.101     -1.587      0.113      -0.358       0.038
# df['L1.log_fci']       0.5828      1.377      0.423      0.672      -2.117       3.283
# df['L1.log_brlem']     0.1806      0.080      2.263      0.024       0.024       0.337
# df['L2.log_ipca']     -4.3894      0.990     -4.432      0.000      -6.331      -2.448
# df['L2.log_pimsa']     0.0291      0.093      0.314      0.754      -0.153       0.211
# df['L2.log_fci']      -1.1449      1.338     -0.856      0.392      -3.768       1.478
# df['L2.log_brlem']     0.0039      0.076      0.052      0.959      -0.144       0.152
# ==============================================================================
# Omnibus:                        0.910   Durbin-Watson:                   0.215
# Prob(Omnibus):                  0.634   Jarque-Bera (JB):                0.890
# Skew:                           0.175   Prob(JB):                        0.641
# Kurtosis:                       2.924   Cond. No.                     1.34e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.34e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.231
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     6.018
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           3.21e-07
# Time:                        14:38:31   Log-Likelihood:                 339.39
# No. Observations:                 165   AIC:                            -658.8
# Df Residuals:                     155   BIC:                            -627.7
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.7778      2.080      0.855      0.393      -2.300       5.855
# df['Choque']           0.0026      0.025      0.105      0.916      -0.046       0.051
# df['L1.log_ipca']      4.2880      1.007      4.257      0.000       2.314       6.262
# df['L1.log_pimsa']    -0.1471      0.104     -1.418      0.156      -0.350       0.056
# df['L1.log_fci']       0.4109      1.383      0.297      0.766      -2.300       3.122
# df['L1.log_brlem']     0.1713      0.081      2.108      0.035       0.012       0.331
# df['L2.log_ipca']     -4.2026      1.009     -4.164      0.000      -6.181      -2.225
# df['L2.log_pimsa']     0.0222      0.094      0.237      0.813      -0.162       0.206
# df['L2.log_fci']      -0.9547      1.337     -0.714      0.475      -3.576       1.666
# df['L2.log_brlem']     0.0146      0.076      0.191      0.848      -0.135       0.164
# ==============================================================================
# Omnibus:                        1.105   Durbin-Watson:                   0.196
# Prob(Omnibus):                  0.575   Jarque-Bera (JB):                1.116
# Skew:                           0.194   Prob(JB):                        0.572
# Kurtosis:                       2.890   Cond. No.                     1.35e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.35e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.220
# Model:                            OLS   Adj. R-squared:                  0.174
# Method:                 Least Squares   F-statistic:                     5.882
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           4.86e-07
# Time:                        14:38:31   Log-Likelihood:                 334.30
# No. Observations:                 164   AIC:                            -648.6
# Df Residuals:                     154   BIC:                            -617.6
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.6443      2.252      0.730      0.465      -2.769       6.057
# df['Choque']           0.0095      0.025      0.380      0.704      -0.040       0.059
# df['L1.log_ipca']      4.1850      1.049      3.991      0.000       2.130       6.240
# df['L1.log_pimsa']    -0.1404      0.107     -1.306      0.192      -0.351       0.070
# df['L1.log_fci']       0.1915      1.410      0.136      0.892      -2.571       2.954
# df['L1.log_brlem']     0.1693      0.086      1.963      0.050       0.000       0.338
# df['L2.log_ipca']     -4.0969      1.049     -3.905      0.000      -6.153      -2.040
# df['L2.log_pimsa']     0.0194      0.096      0.202      0.840      -0.169       0.208
# df['L2.log_fci']      -0.7156      1.347     -0.531      0.595      -3.355       1.924
# df['L2.log_brlem']     0.0186      0.078      0.238      0.812      -0.135       0.172
# ==============================================================================
# Omnibus:                        1.292   Durbin-Watson:                   0.178
# Prob(Omnibus):                  0.524   Jarque-Bera (JB):                1.323
# Skew:                           0.209   Prob(JB):                        0.516
# Kurtosis:                       2.863   Cond. No.                     1.38e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.38e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.214
# Model:                            OLS   Adj. R-squared:                  0.168
# Method:                 Least Squares   F-statistic:                     5.783
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           6.58e-07
# Time:                        14:38:31   Log-Likelihood:                 329.72
# No. Observations:                 163   AIC:                            -639.4
# Df Residuals:                     153   BIC:                            -608.5
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.8112      2.406      0.753      0.452      -2.905       6.527
# df['Choque']           0.0109      0.025      0.432      0.666      -0.038       0.060
# df['L1.log_ipca']      4.0451      1.074      3.767      0.000       1.940       6.150
# df['L1.log_pimsa']    -0.1329      0.111     -1.202      0.229      -0.350       0.084
# df['L1.log_fci']      -0.0694      1.449     -0.048      0.962      -2.909       2.770
# df['L1.log_brlem']     0.1788      0.085      2.097      0.036       0.012       0.346
# df['L2.log_ipca']     -3.9551      1.074     -3.684      0.000      -6.059      -1.851
# df['L2.log_pimsa']     0.0202      0.099      0.203      0.839      -0.175       0.215
# df['L2.log_fci']      -0.5016      1.358     -0.369      0.712      -3.162       2.159
# df['L2.log_brlem']     0.0094      0.078      0.121      0.904      -0.143       0.161
# ==============================================================================
# Omnibus:                        1.537   Durbin-Watson:                   0.164
# Prob(Omnibus):                  0.464   Jarque-Bera (JB):                1.579
# Skew:                           0.228   Prob(JB):                        0.454
# Kurtosis:                       2.841   Cond. No.                     1.40e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.209
# Model:                            OLS   Adj. R-squared:                  0.162
# Method:                 Least Squares   F-statistic:                     5.778
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           6.77e-07
# Time:                        14:38:31   Log-Likelihood:                 325.10
# No. Observations:                 162   AIC:                            -630.2
# Df Residuals:                     152   BIC:                            -599.3
# Df Model:                           9
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.9580      2.733      0.716      0.474      -3.398       7.314
# df['Choque']           0.0071      0.025      0.278      0.781      -0.043       0.057
# df['L1.log_ipca']      3.9642      1.097      3.613      0.000       1.814       6.115
# df['L1.log_pimsa']    -0.1299      0.119     -1.087      0.277      -0.364       0.104
# df['L1.log_fci']      -0.1696      1.668     -0.102      0.919      -3.438       3.099
# df['L1.log_brlem']     0.1720      0.095      1.808      0.071      -0.014       0.358
# df['L2.log_ipca']     -3.8699      1.095     -3.536      0.000      -6.015      -1.725
# df['L2.log_pimsa']     0.0250      0.106      0.235      0.814      -0.183       0.233
# df['L2.log_fci']      -0.4497      1.488     -0.302      0.762      -3.366       2.466
# df['L2.log_brlem']     0.0188      0.083      0.226      0.821      -0.144       0.182
# ==============================================================================
# Omnibus:                        1.501   Durbin-Watson:                   0.162
# Prob(Omnibus):                  0.472   Jarque-Bera (JB):                1.575
# Skew:                           0.220   Prob(JB):                        0.455
# Kurtosis:                       2.799   Cond. No.                     1.46e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 1.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df
# Out:
#          Selic  Selic_d   ibcbr  log_ibcbrsa  ibcbrsa_log       pim     pimsa  \
# date
# 2006-01  17.25     0.00  108.55       113.36     4.730569  83.65213  90.63329
# 2006-02  17.25     0.00  107.80       113.64     4.733036  80.20779  91.37976
# 2006-03  16.50    -0.75  119.09       113.56     4.732331  92.39900  90.76299
# 2006-04  15.75    -0.75  112.61       114.24     4.738301  85.66672  91.32689
# 2006-05  15.75     0.00  117.19       115.65     4.750568  95.35205  91.89632
# ...        ...      ...     ...          ...          ...       ...       ...
# 2022-02  10.75     1.50  136.31       141.71     4.953783  75.87402  85.56588
# 2022-03  11.75     1.00  148.42       143.22     4.964382  84.49285  86.07131
# 2022-04  11.75     0.00  142.17       142.48     4.959202  80.88910  86.20807
# 2022-05  12.75     1.00  142.75       142.11     4.956601  88.75731  86.48873
# 2022-06  13.25     0.50  142.37       143.09     4.963474  87.45102  86.13488
#
#          log_pimsa     pmcsa  pmcsa_log  ...  QoQ_pimsa  L1.log_ipca  \
# date                                     ...
# 2006-01   4.506822  55.37375   4.014106  ...        NaN          NaN
# 2006-02   4.515024  54.72103   4.002248  ...        NaN     7.843990
# 2006-03   4.508252  54.81225   4.003914  ...        NaN     7.848083
# 2006-04   4.514445  55.45193   4.015517  ...   0.007624     7.852373
# 2006-05   4.520661  55.72637   4.020453  ...   0.005637     7.854470
# ...            ...       ...        ...  ...        ...          ...
# 2022-02   4.449287  99.31007   4.598247  ...   0.014358     8.724710
# 2022-03   4.455176  98.57361   4.590804  ...  -0.006213     8.734760
# 2022-04   4.456764  97.51749   4.580032  ...   0.014232     8.750830
# 2022-05   4.460014  97.83140   4.583246  ...   0.010728     8.761375
# 2022-06   4.455914  95.53430   4.559485  ...   0.000738     8.766064
#
#          L1.log_pimsa  L1.log_fci  L1.log_brlem  L2.log_ipca  L2.log_pimsa  \
# date
# 2006-01           NaN         NaN           NaN          NaN           NaN
# 2006-02      4.506822    4.608255      3.821372          NaN           NaN
# 2006-03      4.515024    4.609486      3.861958     7.843990      4.506822
# 2006-04      4.508252    4.611407      3.851362     7.848083      4.515024
# 2006-05      4.514445    4.609333      3.875185     7.852373      4.508252
# ...               ...         ...           ...          ...           ...
# 2022-02      4.442531    4.592971      3.570034     8.719324      4.461390
# 2022-03      4.449287    4.593053      3.620483     8.724710      4.442531
# 2022-04      4.455176    4.593363      3.674674     8.734760      4.449287
# 2022-05      4.456764    4.595396      3.652052     8.750830      4.455176
# 2022-06      4.460014    4.594328      3.687894     8.761375      4.456764
#
#          L2.log_fci  L2.log_brlem    LP_lhs
# date
# 2006-01         NaN           NaN       NaN
# 2006-02         NaN           NaN       NaN
# 2006-03    4.608255      3.821372       NaN
# 2006-04    4.609486      3.861958       NaN
# 2006-05    4.611407      3.851362       NaN
# ...             ...           ...       ...
# 2022-02    4.592501      3.529473  0.190159
# 2022-03    4.592971      3.570034  0.198758
# 2022-04    4.593053      3.620483  0.203619
# 2022-05    4.593363      3.674674  0.207009
# 2022-06    4.595396      3.652052  0.213588
#
# [198 rows x 46 columns]

# %%
# Choice of the maximum horizon for the local projections and organizing to save the results:
horizon = range(0,37)
controls_lag = 2

list_var = [df["log_ipca"], df["log_pimsa"], df["log_fci"], df["log_brlem"]]

for var in list_var:
    for month in horizon:
        df["LP_lhs"] = df[var].diff(month)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 9
#       7 for var in list_var:
#       8     for month in horizon:
# ----> 9         df["LP_lhs"] = df[var].shift(month)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Float64Index([  7.8439898046586, 7.848082798684511, 7.852372986750028,\n              7.854470457736858, 7.855471031793002, 7.853367891830326,\n              7.855265569201007, 7.855765583746732, 7.857863692348301,\n               7.86115680739246,\n              ...\n              8.690172915517794, 8.702594999361983, 8.712050842005915,\n              8.719323911432724,  8.72470967364473, 8.734759619450228,\n              8.750830292350216, 8.761374685142004, 8.766063746982523,\n              8.772741975479123],\n             dtype='float64', length=198)] are in the [columns]"

# %%
for month in horizon:
    pass

# %%
# Choice of the maximum horizon for the local projections and organizing to save the results:
horizon = range(0, 37)
controls_lag = 2

list_var = ["log_ipca", "log_pimsa", "log_fci", "log_brlem"]

# Adiciona as variáveis defasadas ao DataFrame
for col in list_var:
    for lag in range(1, controls_lag + 1):
        df[f"L{lag}.{col}"] = df[col].shift(lag)

# Inicializa os resultados com NaN
for var_name in list_var:
    df[f"LP_b_lhs_{var_name}"] = np.nan
    df[f"LP_se_lhs_{var_name}"] = np.nan

# Starting the regressions for each horizon
for month in horizon:
    # Criando a variável a ser utilizada nas Projeções Locais (LHS):
    df["LP_lhs"] = df["log_ipca"].shift(-month) - df["log_ipca"].shift(1)

    # Definindo a truncagem Newey-West e executando a regressão LP:
    nw_lag_truncation = month + 1
    controls = ["Choque"] + [f"L{lag}.{col}" for col in list_var for lag in range(1, controls_lag + 1)]

    # Alinha os índices antes da regressão
    df_reg = pd.concat([df["LP_lhs"].dropna(), df[["Choque"] + controls].dropna()], axis=1, join="inner")
    
    model = sm.OLS(df_reg["LP_lhs"], sm.add_constant(df_reg[["Choque"] + controls])).fit(cov_type='HAC', cov_kwds={'maxlags': nw_lag_truncation})

    # Salvando o coeficiente de interesse e os erros padrão
    df.loc[df.index[-1], [f"LP_b_lhs_{var_name}", f"LP_se_lhs_{var_name}"]] = [model.params["Choque"], model.bse["Choque"]]

# Limpeza das variáveis auxiliares:
df = df.drop(columns=["x_axis", "ci_ub", "ci_lb"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 36
#      33     model = sm.OLS(df_reg["LP_lhs"], sm.add_constant(df_reg[["Choque"] + controls])).fit(cov_type='HAC', cov_kwds={'maxlags': nw_lag_truncation})
#      35     # Salvando o coeficiente de interesse e os erros padrão
# ---> 36     df.loc[df.index[-1], [f"LP_b_lhs_{var_name}", f"LP_se_lhs_{var_name}"]] = [model.params["Choque"], model.bse["Choque"]]
#      38 # Limpeza das variáveis auxiliares:
#      39 df = df.drop(columns=["x_axis", "ci_ub", "ci_lb"])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:818, in _LocationIndexer.__setitem__(self, key, value)
#     815 self._has_valid_setitem_indexer(key)
#     817 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 818 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1797, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1795     self._setitem_with_indexer_split_path(indexer, value, name)
#    1796 else:
# -> 1797     self._setitem_single_block(indexer, value, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:2078, in _iLocIndexer._setitem_single_block(self, indexer, value, name)
#    2075 self.obj._check_is_chained_assignment_possible()
#    2077 # actually do the set
# -> 2078 self.obj._mgr = self.obj._mgr.setitem(indexer=indexer, value=value)
#    2079 self.obj._maybe_update_cacher(clear=True, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:393, in BaseBlockManager.setitem(self, indexer, value)
#     388 if _using_copy_on_write() and not self._has_no_reference(0):
#     389     # if being referenced -> perform Copy-on-Write and clear the reference
#     390     # this method is only called if there is a single block -> hardcoded 0
#     391     self = self.copy()
# --> 393 return self.apply("setitem", indexer=indexer, value=value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:986, in Block.setitem(self, indexer, value)
#     982         if lib.is_list_like(vi):
#     983             # checking lib.is_scalar here fails on
#     984             #  test_iloc_setitem_custom_object
#     985             casted = setitem_datetimelike_compat(values, len(vi), casted)
# --> 986     values[indexer] = casted
#     987 return self
#
# ValueError: shape mismatch: value array of shape (2,4) could not be broadcast to indexing result of shape (2,)
