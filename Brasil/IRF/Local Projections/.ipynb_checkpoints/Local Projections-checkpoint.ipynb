# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np

# %%
# Leitura do Excel e conversão das variáveis na primeira linha para strings
df = pd.read_excel("Narrative_MP_Brazil_Dataset_with_Controls.xlsx", sheet_name="IPCA")
df.iloc[0] = df.iloc[0].astype(str)

# Coerção das colunas (exceto 'Data') para numéricas
df[df.columns[1:]] = df[df.columns[1:]].apply(pd.to_numeric, errors='coerce')

# Criando a variável de data
df['date'] = pd.to_datetime(df['Data'], format='%d-%m-%Y')

# Formatando a variável de data
df['date'] = df['date'].dt.to_period('M')

# Ordenando o DataFrame pela variável de data
df = df.sort_values('date')

# Configurando a série temporal
df = df.set_index('date')

# Descartando a variável 'Data'
df = df.drop(columns=['Data'])

# %%
df.head()
# Out:
#          Selic  Selic_d   ibcbr  ibcbrsa  ibcbrsa_log       pim     pimsa  \
# date
# 2006-01  17.25     0.00  108.55   113.36     4.730569  83.65213  90.63329
# 2006-02  17.25     0.00  107.80   113.64     4.733036  80.20779  91.37976
# 2006-03  16.50    -0.75  119.09   113.56     4.732331  92.39900  90.76299
# 2006-04  15.75    -0.75  112.61   114.24     4.738301  85.66672  91.32689
# 2006-05  15.75     0.00  117.19   115.65     4.750568  95.35205  91.89632
#
#          pimsa_log     pmcsa  pmcsa_log  ...     fgv_ind  fgv_ind_log  \
# date                                     ...
# 2006-01   4.506822  55.37375   4.014106  ...  120.771282     4.793899
# 2006-02   4.515024  54.72103   4.002248  ...  121.915021     4.803324
# 2006-03   4.508252  54.81225   4.003914  ...  121.594866     4.800695
# 2006-04   4.514445  55.45193   4.015517  ...  119.820464     4.785994
# 2006-05   4.520661  55.72637   4.020453  ...  120.083283     4.788186
#
#            fgv_serv  fgv_serv_log  logbrlem    logfci    ff4_tc    Choque  \
# date
# 2006-01  133.507340      4.894156  3.821372  4.608255 -0.177879  0.073583
# 2006-02  133.479233      4.893946  3.861958  4.609486  0.000000  0.000000
# 2006-03  133.933161      4.897341  3.851362  4.611407 -0.075017 -0.034759
# 2006-04  135.860118      4.911626  3.875185  4.609333  0.018302  0.002962
# 2006-05  134.599264      4.902302  3.809868  4.609002  0.000000  0.000000
#
#          Choque_pos  Choque_neg
# date
# 2006-01    0.073583    0.073583
# 2006-02    0.000000    0.000000
# 2006-03   -0.034759   -0.034759
# 2006-04    0.002962    0.002962
# 2006-05    0.000000    0.000000
#
# [5 rows x 24 columns]

# %%
# Renomeando colunas
df.rename(columns={'logbrlem': 'log_brlem', 'logfci': 'log_fci', 'ipca_log': 'log_ipca',
                   'pimsa_log': 'log_pimsa', 'ibcbrsa': 'log_ibcbrsa'}, inplace=True)


# Criando variáveis de mudanças percentuais mensais (MoM)
df['D_log_ipca'] = df['log_ipca'].diff()
df['D_log_pimsa'] = df['log_pimsa'].diff()
df['D_log_brlem'] = df['log_brlem'].diff()
df['D_log_fci'] = df['log_fci'].diff()

# Criando variáveis de mudanças percentuais anuais (YoY)
df['YoY_selic'] = df['Selic'] - df['Selic'].shift(12)
df['YoY_ipca'] = df['log_ipca'] - df['log_ipca'].shift(12)
df['YoY_pimsa'] = df['log_pimsa'] - df['log_pimsa'].shift(12)

# Criando variáveis de mudanças nas somas dos últimos seis meses (SoS)
df['SoS_selic'] = df['Selic'] - df['Selic'].shift(6)
df['SoS_ipca'] = df['log_ipca'] - df['log_ipca'].shift(6)
df['SoS_pimsa'] = df['log_pimsa'] - df['log_pimsa'].shift(6)

# Criando variáveis de mudanças nas somas dos últimos três meses (QoQ)
df['QoQ_selic'] = df['Selic'] - df['Selic'].shift(3)
df['QoQ_ipca'] = df['log_ipca'] - df['log_ipca'].shift(3)
df['QoQ_pimsa'] = df['log_pimsa'] - df['log_pimsa'].shift(3)

# %%
# Definindo o número de lags para suas variáveis de controle
controls_lag = 2

# Definindo o horizonte = 36
horizon = range(1,38)

# Adicionando variáveis defasadas ao DataFrame
list_var = ["log_ipca", "log_pimsa", "log_fci", "log_brlem"]
list_control = ["Selic","log_ipca", "log_pimsa", "log_fci", "log_brlem"]

for variable in list_var:

    for month in horizon:
        df["LP_lhs"] = df[variable].diff(month)
        df["LP_lhs"] = df["LP_lhs"].shift(-month+1)


        for lag in range(1, controls_lag + 1):
            for control in list_control:
                df[f"L{lag}.{control}"] = df[control].shift(lag)

        # Construindo a fórmula da regressão
        lagged_controls = [f"L{i}.{control}" for i in range(1, controls_lag + 1) for control in list_control]
        lagged_controls_str = ' + '.join([f"df['{control}']" for control in lagged_controls])

        formula = f"df['LP_lhs'] ~ df['Choque'] + {lagged_controls_str}"
        nw_lag_truncation = month + 1

        # Executando a regressão com erros padrão robustos
        model = sm.OLS.from_formula(formula, data=df).fit(cov_type='HAC', cov_kwds={'maxlags': nw_lag_truncation})

        # Imprimindo o resumo
        print(month)
        print(model.summary())
# Out:
# 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.423
# Model:                            OLS   Adj. R-squared:                  0.388
# Method:                 Least Squares   F-statistic:                     13.33
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           1.56e-18
# Time:                        16:59:54   Log-Likelihood:                 897.58
# No. Observations:                 196   AIC:                            -1771.
# Df Residuals:                     184   BIC:                            -1732.
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.1905      0.157      1.217      0.224      -0.116       0.497
# df['Choque']          -0.0011      0.003     -0.371      0.710      -0.007       0.005
# df['L1.Selic']         0.0003      0.001      0.607      0.544      -0.001       0.001
# df['L1.log_ipca']      0.4705      0.079      5.949      0.000       0.315       0.626
# df['L1.log_pimsa']     0.0050      0.014      0.354      0.723      -0.023       0.033
# df['L1.log_fci']       0.0699      0.100      0.702      0.483      -0.125       0.265
# df['L1.log_brlem']     0.0026      0.007      0.377      0.706      -0.011       0.016
# df['L2.Selic']        -0.0003      0.001     -0.549      0.583      -0.001       0.001
# df['L2.log_ipca']     -0.4700      0.079     -5.942      0.000      -0.625      -0.315
# df['L2.log_pimsa']     0.0080      0.013      0.592      0.554      -0.018       0.034
# df['L2.log_fci']      -0.1191      0.096     -1.241      0.214      -0.307       0.069
# df['L2.log_brlem']    -0.0089      0.006     -1.411      0.158      -0.021       0.003
# ==============================================================================
# Omnibus:                        6.610   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.037   Jarque-Bera (JB):               10.812
# Skew:                          -0.046   Prob(JB):                      0.00449
# Kurtosis:                       4.147   Cond. No.                     2.10e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 2 lags and without small sample correction
# [2] The condition number is large, 2.1e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.422
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     10.86
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           2.60e-15
# Time:                        16:59:54   Log-Likelihood:                 778.51
# No. Observations:                 195   AIC:                            -1533.
# Df Residuals:                     183   BIC:                            -1494.
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.4533      0.331      1.371      0.170      -0.195       1.101
# df['Choque']          -0.0080      0.004     -1.809      0.071      -0.017       0.001
# df['L1.Selic']         0.0013      0.001      1.502      0.133      -0.000       0.003
# df['L1.log_ipca']      0.6288      0.156      4.040      0.000       0.324       0.934
# df['L1.log_pimsa']     0.0201      0.020      1.001      0.317      -0.019       0.059
# df['L1.log_fci']       0.1664      0.191      0.870      0.384      -0.208       0.541
# df['L1.log_brlem']    -0.0020      0.011     -0.193      0.847      -0.023       0.019
# df['L2.Selic']        -0.0013      0.001     -1.391      0.164      -0.003       0.001
# df['L2.log_ipca']     -0.6278      0.156     -4.032      0.000      -0.933      -0.323
# df['L2.log_pimsa']     0.0130      0.022      0.590      0.555      -0.030       0.056
# df['L2.log_fci']      -0.2841      0.186     -1.529      0.126      -0.648       0.080
# df['L2.log_brlem']    -0.0143      0.009     -1.534      0.125      -0.033       0.004
# ==============================================================================
# Omnibus:                        0.175   Durbin-Watson:                   1.059
# Prob(Omnibus):                  0.916   Jarque-Bera (JB):                0.099
# Skew:                          -0.055   Prob(JB):                        0.952
# Kurtosis:                       3.007   Cond. No.                     2.10e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 3 lags and without small sample correction
# [2] The condition number is large, 2.1e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.421
# Model:                            OLS   Adj. R-squared:                  0.386
# Method:                 Least Squares   F-statistic:                     11.68
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           2.22e-16
# Time:                        16:59:54   Log-Likelihood:                 710.34
# No. Observations:                 194   AIC:                            -1397.
# Df Residuals:                     182   BIC:                            -1357.
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.9113      0.560      1.627      0.104      -0.187       2.009
# df['Choque']          -0.0094      0.005     -1.919      0.055      -0.019       0.000
# df['L1.Selic']         0.0013      0.001      1.092      0.275      -0.001       0.004
# df['L1.log_ipca']      0.7303      0.194      3.762      0.000       0.350       1.111
# df['L1.log_pimsa']     0.0430      0.019      2.282      0.022       0.006       0.080
# df['L1.log_fci']      -0.0104      0.245     -0.043      0.966      -0.491       0.470
# df['L1.log_brlem']    -0.0053      0.013     -0.394      0.693      -0.031       0.021
# df['L2.Selic']        -0.0013      0.001     -0.979      0.328      -0.004       0.001
# df['L2.log_ipca']     -0.7288      0.194     -3.753      0.000      -1.109      -0.348
# df['L2.log_pimsa']     0.0096      0.022      0.427      0.670      -0.034       0.053
# df['L2.log_fci']      -0.2175      0.244     -0.891      0.373      -0.696       0.261
# df['L2.log_brlem']    -0.0212      0.011     -1.844      0.065      -0.044       0.001
# ==============================================================================
# Omnibus:                        0.626   Durbin-Watson:                   0.653
# Prob(Omnibus):                  0.731   Jarque-Bera (JB):                0.447
# Skew:                          -0.113   Prob(JB):                        0.800
# Kurtosis:                       3.065   Cond. No.                     2.10e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 4 lags and without small sample correction
# [2] The condition number is large, 2.1e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 4
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.403
# Model:                            OLS   Adj. R-squared:                  0.366
# Method:                 Least Squares   F-statistic:                     12.63
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           1.44e-17
# Time:                        16:59:54   Log-Likelihood:                 659.64
# No. Observations:                 193   AIC:                            -1295.
# Df Residuals:                     181   BIC:                            -1256.
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.3713      0.828      1.655      0.098      -0.252       2.995
# df['Choque']          -0.0084      0.006     -1.465      0.143      -0.020       0.003
# df['L1.Selic']         0.0022      0.002      1.381      0.167      -0.001       0.005
# df['L1.log_ipca']      0.7105      0.230      3.083      0.002       0.259       1.162
# df['L1.log_pimsa']     0.0666      0.025      2.688      0.007       0.018       0.115
# df['L1.log_fci']      -0.1632      0.341     -0.479      0.632      -0.831       0.505
# df['L1.log_brlem']    -0.0164      0.019     -0.855      0.392      -0.054       0.021
# df['L2.Selic']        -0.0021      0.002     -1.259      0.208      -0.005       0.001
# df['L2.log_ipca']     -0.7090      0.230     -3.085      0.002      -1.159      -0.259
# df['L2.log_pimsa']     0.0006      0.029      0.019      0.985      -0.056       0.057
# df['L2.log_fci']      -0.1707      0.318     -0.537      0.591      -0.793       0.452
# df['L2.log_brlem']    -0.0187      0.017     -1.118      0.264      -0.052       0.014
# ==============================================================================
# Omnibus:                        0.884   Durbin-Watson:                   0.501
# Prob(Omnibus):                  0.643   Jarque-Bera (JB):                0.667
# Skew:                          -0.138   Prob(JB):                        0.717
# Kurtosis:                       3.085   Cond. No.                     2.10e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 5 lags and without small sample correction
# [2] The condition number is large, 2.1e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 5
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.387
# Model:                            OLS   Adj. R-squared:                  0.350
# Method:                 Least Squares   F-statistic:                     12.82
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           8.78e-18
# Time:                        16:59:54   Log-Likelihood:                 622.80
# No. Observations:                 192   AIC:                            -1222.
# Df Residuals:                     180   BIC:                            -1183.
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.6553      1.080      1.533      0.125      -0.461       3.771
# df['Choque']          -0.0082      0.007     -1.142      0.253      -0.022       0.006
# df['L1.Selic']         0.0040      0.002      1.960      0.050    9.66e-07       0.008
# df['L1.log_ipca']      0.5486      0.260      2.107      0.035       0.038       1.059
# df['L1.log_pimsa']     0.0770      0.033      2.326      0.020       0.012       0.142
# df['L1.log_fci']      -0.1522      0.435     -0.350      0.727      -1.005       0.701
# df['L1.log_brlem']    -0.0235      0.022     -1.064      0.287      -0.067       0.020
# df['L2.Selic']        -0.0040      0.002     -1.844      0.065      -0.008       0.000
# df['L2.log_ipca']     -0.5483      0.259     -2.116      0.034      -1.056      -0.041
# df['L2.log_pimsa']     0.0034      0.042      0.082      0.934      -0.078       0.085
# df['L2.log_fci']      -0.2453      0.375     -0.655      0.513      -0.980       0.489
# df['L2.log_brlem']    -0.0208      0.019     -1.107      0.268      -0.058       0.016
# ==============================================================================
# Omnibus:                        0.577   Durbin-Watson:                   0.391
# Prob(Omnibus):                  0.749   Jarque-Bera (JB):                0.341
# Skew:                          -0.085   Prob(JB):                        0.843
# Kurtosis:                       3.117   Cond. No.                     2.11e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 6 lags and without small sample correction
# [2] The condition number is large, 2.11e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 6
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.384
# Model:                            OLS   Adj. R-squared:                  0.346
# Method:                 Least Squares   F-statistic:                     11.89
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           1.40e-16
# Time:                        16:59:54   Log-Likelihood:                 595.70
# No. Observations:                 191   AIC:                            -1167.
# Df Residuals:                     179   BIC:                            -1128.
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.8773      1.325      1.417      0.157      -0.720       4.475
# df['Choque']          -0.0027      0.009     -0.285      0.775      -0.021       0.016
# df['L1.Selic']         0.0053      0.002      2.139      0.032       0.000       0.010
# df['L1.log_ipca']      0.4065      0.279      1.456      0.145      -0.141       0.953
# df['L1.log_pimsa']     0.0868      0.031      2.807      0.005       0.026       0.147
# df['L1.log_fci']      -0.1793      0.454     -0.395      0.693      -1.069       0.711
# df['L1.log_brlem']    -0.0337      0.024     -1.419      0.156      -0.080       0.013
# df['L2.Selic']        -0.0054      0.003     -2.063      0.039      -0.011      -0.000
# df['L2.log_ipca']     -0.4082      0.278     -1.469      0.142      -0.953       0.136
# df['L2.log_pimsa']     0.0041      0.044      0.092      0.927      -0.083       0.091
# df['L2.log_fci']      -0.2653      0.374     -0.709      0.478      -0.999       0.468
# df['L2.log_brlem']    -0.0181      0.021     -0.880      0.379      -0.058       0.022
# ==============================================================================
# Omnibus:                        0.170   Durbin-Watson:                   0.333
# Prob(Omnibus):                  0.918   Jarque-Bera (JB):                0.058
# Skew:                           0.039   Prob(JB):                        0.972
# Kurtosis:                       3.034   Cond. No.                     2.12e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 7 lags and without small sample correction
# [2] The condition number is large, 2.12e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 7
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.389
# Model:                            OLS   Adj. R-squared:                  0.351
# Method:                 Least Squares   F-statistic:                     9.597
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           1.66e-13
# Time:                        16:59:54   Log-Likelihood:                 574.36
# No. Observations:                 190   AIC:                            -1125.
# Df Residuals:                     178   BIC:                            -1086.
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.0468      1.599      1.280      0.200      -1.087       5.180
# df['Choque']          -0.0054      0.011     -0.507      0.612      -0.026       0.015
# df['L1.Selic']         0.0065      0.003      2.245      0.025       0.001       0.012
# df['L1.log_ipca']      0.3022      0.311      0.971      0.332      -0.308       0.912
# df['L1.log_pimsa']     0.0933      0.032      2.907      0.004       0.030       0.156
# df['L1.log_fci']      -0.2797      0.545     -0.513      0.608      -1.349       0.789
# df['L1.log_brlem']    -0.0408      0.025     -1.606      0.108      -0.091       0.009
# df['L2.Selic']        -0.0068      0.003     -2.222      0.026      -0.013      -0.001
# df['L2.log_ipca']     -0.3055      0.311     -0.983      0.326      -0.915       0.304
# df['L2.log_pimsa']     0.0110      0.050      0.218      0.827      -0.088       0.109
# df['L2.log_fci']      -0.2033      0.390     -0.521      0.602      -0.967       0.561
# df['L2.log_brlem']    -0.0198      0.022     -0.911      0.362      -0.062       0.023
# ==============================================================================
# Omnibus:                        1.165   Durbin-Watson:                   0.287
# Prob(Omnibus):                  0.559   Jarque-Bera (JB):                1.136
# Skew:                           0.186   Prob(JB):                        0.567
# Kurtosis:                       2.932   Cond. No.                     2.13e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 8 lags and without small sample correction
# [2] The condition number is large, 2.13e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 8
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.400
# Model:                            OLS   Adj. R-squared:                  0.363
# Method:                 Least Squares   F-statistic:                     8.703
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           3.02e-12
# Time:                        16:59:54   Log-Likelihood:                 557.30
# No. Observations:                 189   AIC:                            -1091.
# Df Residuals:                     177   BIC:                            -1052.
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.8952      1.819      1.042      0.298      -1.670       5.461
# df['Choque']          -0.0101      0.012     -0.823      0.411      -0.034       0.014
# df['L1.Selic']         0.0072      0.003      2.218      0.027       0.001       0.014
# df['L1.log_ipca']      0.2998      0.364      0.822      0.411      -0.415       1.014
# df['L1.log_pimsa']     0.0895      0.033      2.714      0.007       0.025       0.154
# df['L1.log_fci']      -0.0821      0.662     -0.124      0.901      -1.379       1.215
# df['L1.log_brlem']    -0.0571      0.028     -2.055      0.040      -0.112      -0.003
# df['L2.Selic']        -0.0076      0.003     -2.214      0.027      -0.014      -0.001
# df['L2.log_ipca']     -0.3049      0.365     -0.835      0.403      -1.020       0.410
# df['L2.log_pimsa']     0.0315      0.051      0.623      0.533      -0.068       0.130
# df['L2.log_fci']      -0.3724      0.436     -0.854      0.393      -1.227       0.482
# df['L2.log_brlem']    -0.0124      0.023     -0.537      0.591      -0.057       0.033
# ==============================================================================
# Omnibus:                        3.713   Durbin-Watson:                   0.263
# Prob(Omnibus):                  0.156   Jarque-Bera (JB):                3.780
# Skew:                           0.326   Prob(JB):                        0.151
# Kurtosis:                       2.763   Cond. No.                     2.16e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# [2] The condition number is large, 2.16e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 9
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.369
# Method:                 Least Squares   F-statistic:                     7.690
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           8.73e-11
# Time:                        16:59:54   Log-Likelihood:                 541.26
# No. Observations:                 188   AIC:                            -1059.
# Df Residuals:                     176   BIC:                            -1020.
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.9908      2.022      0.984      0.325      -1.973       5.955
# df['Choque']          -0.0071      0.013     -0.558      0.577      -0.032       0.018
# df['L1.Selic']         0.0063      0.004      1.711      0.087      -0.001       0.014
# df['L1.log_ipca']      0.4735      0.430      1.102      0.270      -0.369       1.315
# df['L1.log_pimsa']     0.0985      0.033      2.973      0.003       0.034       0.163
# df['L1.log_fci']      -0.0830      0.741     -0.112      0.911      -1.536       1.370
# df['L1.log_brlem']    -0.0603      0.031     -1.923      0.054      -0.122       0.001
# df['L2.Selic']        -0.0069      0.004     -1.779      0.075      -0.015       0.001
# df['L2.log_ipca']     -0.4801      0.431     -1.115      0.265      -1.324       0.364
# df['L2.log_pimsa']     0.0371      0.053      0.695      0.487      -0.068       0.142
# df['L2.log_fci']      -0.3965      0.472     -0.839      0.401      -1.323       0.529
# df['L2.log_brlem']    -0.0166      0.027     -0.609      0.543      -0.070       0.037
# ==============================================================================
# Omnibus:                        5.285   Durbin-Watson:                   0.230
# Prob(Omnibus):                  0.071   Jarque-Bera (JB):                5.409
# Skew:                           0.398   Prob(JB):                       0.0669
# Kurtosis:                       2.759   Cond. No.                     2.15e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 10 lags and without small sample correction
# [2] The condition number is large, 2.15e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 10
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.414
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     7.817
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           5.87e-11
# Time:                        16:59:54   Log-Likelihood:                 526.96
# No. Observations:                 187   AIC:                            -1030.
# Df Residuals:                     175   BIC:                            -991.1
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.9786      2.203      0.898      0.369      -2.339       6.296
# df['Choque']          -0.0105      0.015     -0.705      0.481      -0.040       0.019
# df['L1.Selic']         0.0059      0.004      1.567      0.117      -0.001       0.013
# df['L1.log_ipca']      0.6782      0.471      1.441      0.150      -0.244       1.601
# df['L1.log_pimsa']     0.1005      0.034      2.933      0.003       0.033       0.168
# df['L1.log_fci']       0.0536      0.822      0.065      0.948      -1.557       1.664
# df['L1.log_brlem']    -0.0652      0.036     -1.813      0.070      -0.136       0.005
# df['L2.Selic']        -0.0068      0.004     -1.691      0.091      -0.015       0.001
# df['L2.log_ipca']     -0.6869      0.471     -1.457      0.145      -1.611       0.237
# df['L2.log_pimsa']     0.0464      0.057      0.812      0.417      -0.066       0.159
# df['L2.log_fci']      -0.5321      0.503     -1.058      0.290      -1.518       0.453
# df['L2.log_brlem']    -0.0170      0.033     -0.513      0.608      -0.082       0.048
# ==============================================================================
# Omnibus:                        5.830   Durbin-Watson:                   0.219
# Prob(Omnibus):                  0.054   Jarque-Bera (JB):                5.957
# Skew:                           0.433   Prob(JB):                       0.0509
# Kurtosis:                       2.877   Cond. No.                     2.15e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 11 lags and without small sample correction
# [2] The condition number is large, 2.15e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 11
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.419
# Model:                            OLS   Adj. R-squared:                  0.382
# Method:                 Least Squares   F-statistic:                     9.106
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           9.15e-13
# Time:                        16:59:54   Log-Likelihood:                 513.03
# No. Observations:                 186   AIC:                            -1002.
# Df Residuals:                     174   BIC:                            -963.4
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.0122      2.381      0.845      0.398      -2.654       6.679
# df['Choque']          -0.0106      0.015     -0.723      0.470      -0.039       0.018
# df['L1.Selic']         0.0041      0.004      1.084      0.278      -0.003       0.012
# df['L1.log_ipca']      0.9360      0.500      1.870      0.061      -0.045       1.917
# df['L1.log_pimsa']     0.0901      0.037      2.416      0.016       0.017       0.163
# df['L1.log_fci']       0.1656      0.852      0.195      0.846      -1.504       1.835
# df['L1.log_brlem']    -0.0686      0.039     -1.760      0.078      -0.145       0.008
# df['L2.Selic']        -0.0052      0.004     -1.274      0.203      -0.013       0.003
# df['L2.log_ipca']     -0.9465      0.501     -1.891      0.059      -1.928       0.035
# df['L2.log_pimsa']     0.0709      0.062      1.147      0.251      -0.050       0.192
# df['L2.log_fci']      -0.6562      0.501     -1.309      0.190      -1.638       0.326
# df['L2.log_brlem']    -0.0190      0.037     -0.507      0.612      -0.092       0.054
# ==============================================================================
# Omnibus:                        5.662   Durbin-Watson:                   0.208
# Prob(Omnibus):                  0.059   Jarque-Bera (JB):                5.583
# Skew:                           0.424   Prob(JB):                       0.0613
# Kurtosis:                       3.018   Cond. No.                     2.15e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 12 lags and without small sample correction
# [2] The condition number is large, 2.15e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 12
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.425
# Model:                            OLS   Adj. R-squared:                  0.388
# Method:                 Least Squares   F-statistic:                     10.75
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           5.75e-15
# Time:                        16:59:54   Log-Likelihood:                 499.93
# No. Observations:                 185   AIC:                            -975.9
# Df Residuals:                     173   BIC:                            -937.2
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.1525      2.534      0.849      0.396      -2.814       7.119
# df['Choque']          -0.0136      0.015     -0.917      0.359      -0.043       0.015
# df['L1.Selic']         0.0028      0.004      0.724      0.469      -0.005       0.010
# df['L1.log_ipca']      1.0716      0.501      2.140      0.032       0.090       2.053
# df['L1.log_pimsa']     0.1012      0.039      2.589      0.010       0.025       0.178
# df['L1.log_fci']       0.2290      0.932      0.246      0.806      -1.597       2.055
# df['L1.log_brlem']    -0.0638      0.043     -1.474      0.141      -0.149       0.021
# df['L2.Selic']        -0.0042      0.004     -0.970      0.332      -0.013       0.004
# df['L2.log_ipca']     -1.0837      0.499     -2.172      0.030      -2.062      -0.106
# df['L2.log_pimsa']     0.0763      0.067      1.134      0.257      -0.056       0.208
# df['L2.log_fci']      -0.7570      0.538     -1.407      0.159      -1.811       0.297
# df['L2.log_brlem']    -0.0299      0.043     -0.695      0.487      -0.114       0.055
# ==============================================================================
# Omnibus:                        5.856   Durbin-Watson:                   0.191
# Prob(Omnibus):                  0.053   Jarque-Bera (JB):                5.470
# Skew:                           0.395   Prob(JB):                       0.0649
# Kurtosis:                       3.290   Cond. No.                     2.15e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 13 lags and without small sample correction
# [2] The condition number is large, 2.15e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 13
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.426
# Model:                            OLS   Adj. R-squared:                  0.389
# Method:                 Least Squares   F-statistic:                     11.54
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           5.73e-16
# Time:                        16:59:54   Log-Likelihood:                 486.78
# No. Observations:                 184   AIC:                            -949.6
# Df Residuals:                     172   BIC:                            -911.0
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.3317      2.704      0.862      0.389      -2.968       7.632
# df['Choque']          -0.0119      0.016     -0.737      0.461      -0.044       0.020
# df['L1.Selic']         0.0018      0.004      0.467      0.641      -0.006       0.009
# df['L1.log_ipca']      1.1633      0.485      2.396      0.017       0.212       2.115
# df['L1.log_pimsa']     0.1023      0.039      2.612      0.009       0.026       0.179
# df['L1.log_fci']       0.4056      0.976      0.415      0.678      -1.508       2.319
# df['L1.log_brlem']    -0.0849      0.042     -2.010      0.044      -0.168      -0.002
# df['L2.Selic']        -0.0034      0.004     -0.780      0.435      -0.012       0.005
# df['L2.log_ipca']     -1.1775      0.481     -2.448      0.014      -2.120      -0.235
# df['L2.log_pimsa']     0.0857      0.072      1.195      0.232      -0.055       0.226
# df['L2.log_fci']      -0.9746      0.571     -1.708      0.088      -2.093       0.144
# df['L2.log_brlem']    -0.0121      0.038     -0.322      0.747      -0.086       0.062
# ==============================================================================
# Omnibus:                        5.914   Durbin-Watson:                   0.199
# Prob(Omnibus):                  0.052   Jarque-Bera (JB):                5.608
# Skew:                           0.359   Prob(JB):                       0.0606
# Kurtosis:                       3.464   Cond. No.                     2.14e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 14 lags and without small sample correction
# [2] The condition number is large, 2.14e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 14
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.378
# Method:                 Least Squares   F-statistic:                     12.44
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           4.53e-17
# Time:                        16:59:54   Log-Likelihood:                 472.77
# No. Observations:                 183   AIC:                            -921.5
# Df Residuals:                     171   BIC:                            -883.0
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.6360      2.931      0.899      0.368      -3.108       8.380
# df['Choque']          -0.0154      0.016     -0.938      0.348      -0.048       0.017
# df['L1.Selic']        -0.0001      0.004     -0.032      0.975      -0.008       0.008
# df['L1.log_ipca']      1.1365      0.494      2.300      0.021       0.168       2.105
# df['L1.log_pimsa']     0.1147      0.042      2.715      0.007       0.032       0.197
# df['L1.log_fci']       0.2425      1.020      0.238      0.812      -1.756       2.241
# df['L1.log_brlem']    -0.0926      0.040     -2.292      0.022      -0.172      -0.013
# df['L2.Selic']        -0.0017      0.005     -0.376      0.707      -0.011       0.007
# df['L2.log_ipca']     -1.1517      0.487     -2.363      0.018      -2.107      -0.196
# df['L2.log_pimsa']     0.0886      0.082      1.086      0.278      -0.071       0.249
# df['L2.log_fci']      -0.8859      0.623     -1.422      0.155      -2.107       0.335
# df['L2.log_brlem']    -0.0089      0.034     -0.262      0.794      -0.075       0.058
# ==============================================================================
# Omnibus:                        7.537   Durbin-Watson:                   0.189
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                7.778
# Skew:                           0.381   Prob(JB):                       0.0205
# Kurtosis:                       3.662   Cond. No.                     2.14e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 15 lags and without small sample correction
# [2] The condition number is large, 2.14e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 15
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                     11.89
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           2.29e-16
# Time:                        16:59:54   Log-Likelihood:                 460.42
# No. Observations:                 182   AIC:                            -896.8
# Df Residuals:                     170   BIC:                            -858.4
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.7989      3.213      0.871      0.384      -3.499       9.096
# df['Choque']          -0.0192      0.017     -1.126      0.260      -0.053       0.014
# df['L1.Selic']        -0.0005      0.004     -0.119      0.905      -0.009       0.008
# df['L1.log_ipca']      1.2126      0.467      2.598      0.009       0.298       2.127
# df['L1.log_pimsa']     0.1167      0.047      2.503      0.012       0.025       0.208
# df['L1.log_fci']       0.2164      1.056      0.205      0.838      -1.854       2.287
# df['L1.log_brlem']    -0.1098      0.042     -2.623      0.009      -0.192      -0.028
# df['L2.Selic']        -0.0016      0.005     -0.332      0.740      -0.011       0.008
# df['L2.log_ipca']     -1.2292      0.461     -2.666      0.008      -2.133      -0.325
# df['L2.log_pimsa']     0.0896      0.091      0.983      0.326      -0.089       0.268
# df['L2.log_fci']      -0.8950      0.672     -1.332      0.183      -2.212       0.422
# df['L2.log_brlem']     0.0097      0.033      0.289      0.772      -0.056       0.075
# ==============================================================================
# Omnibus:                       10.621   Durbin-Watson:                   0.176
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               12.020
# Skew:                           0.459   Prob(JB):                      0.00245
# Kurtosis:                       3.862   Cond. No.                     2.14e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 16 lags and without small sample correction
# [2] The condition number is large, 2.14e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 16
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.389
# Model:                            OLS   Adj. R-squared:                  0.349
# Method:                 Least Squares   F-statistic:                     10.48
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           1.57e-14
# Time:                        16:59:54   Log-Likelihood:                 446.92
# No. Observations:                 181   AIC:                            -869.8
# Df Residuals:                     169   BIC:                            -831.5
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              3.0956      3.562      0.869      0.385      -3.886      10.078
# df['Choque']          -0.0153      0.019     -0.821      0.412      -0.052       0.021
# df['L1.Selic']        -0.0010      0.005     -0.216      0.829      -0.010       0.008
# df['L1.log_ipca']      0.9982      0.457      2.186      0.029       0.103       1.893
# df['L1.log_pimsa']     0.1307      0.048      2.711      0.007       0.036       0.225
# df['L1.log_fci']       0.2314      1.112      0.208      0.835      -1.949       2.412
# df['L1.log_brlem']    -0.1157      0.043     -2.665      0.008      -0.201      -0.031
# df['L2.Selic']        -0.0014      0.005     -0.260      0.795      -0.012       0.009
# df['L2.log_ipca']     -1.0157      0.451     -2.252      0.024      -1.900      -0.132
# df['L2.log_pimsa']     0.0849      0.093      0.918      0.359      -0.097       0.266
# df['L2.log_fci']      -0.9784      0.755     -1.295      0.195      -2.459       0.502
# df['L2.log_brlem']     0.0136      0.036      0.376      0.707      -0.057       0.084
# ==============================================================================
# Omnibus:                       13.102   Durbin-Watson:                   0.166
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.340
# Skew:                           0.532   Prob(JB):                     0.000467
# Kurtosis:                       3.949   Cond. No.                     2.15e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 17 lags and without small sample correction
# [2] The condition number is large, 2.15e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 17
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.371
# Model:                            OLS   Adj. R-squared:                  0.330
# Method:                 Least Squares   F-statistic:                     10.38
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           2.22e-14
# Time:                        16:59:55   Log-Likelihood:                 435.06
# No. Observations:                 180   AIC:                            -846.1
# Df Residuals:                     168   BIC:                            -807.8
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              3.3605      3.919      0.857      0.391      -4.321      11.042
# df['Choque']          -0.0234      0.027     -0.865      0.387      -0.076       0.030
# ...
# df['L1.log_fci']       2.5007      2.888      0.866      0.386      -3.159       8.160
# df['L1.log_brlem']    -0.6802      0.093     -7.285      0.000      -0.863      -0.497
# df['L2.Selic']        -0.0206      0.016     -1.272      0.203      -0.052       0.011
# df['L2.log_ipca']     -0.9286      2.694     -0.345      0.730      -6.209       4.351
# df['L2.log_pimsa']    -0.2555      0.170     -1.507      0.132      -0.588       0.077
# df['L2.log_fci']      -6.9294      2.770     -2.501      0.012     -12.359      -1.500
# df['L2.log_brlem']     0.2185      0.082      2.666      0.008       0.058       0.379
# ==============================================================================
# Omnibus:                        2.273   Durbin-Watson:                   0.313
# Prob(Omnibus):                  0.321   Jarque-Bera (JB):                2.102
# Skew:                          -0.276   Prob(JB):                        0.350
# Kurtosis:                       2.999   Cond. No.                     2.55e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 33 lags and without small sample correction
# [2] The condition number is large, 2.55e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 33
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                     103.8
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           7.63e-65
# Time:                        17:00:02   Log-Likelihood:                 217.70
# No. Observations:                 164   AIC:                            -411.4
# Df Residuals:                     152   BIC:                            -374.2
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             33.1253      7.104      4.663      0.000      19.202      47.049
# df['Choque']           0.0463      0.053      0.877      0.380      -0.057       0.150
# df['L1.Selic']         0.0343      0.009      3.750      0.000       0.016       0.052
# df['L1.log_ipca']      0.6218      2.489      0.250      0.803      -4.256       5.499
# df['L1.log_pimsa']    -0.1545      0.115     -1.349      0.177      -0.379       0.070
# df['L1.log_fci']       0.2725      2.416      0.113      0.910      -4.463       5.008
# df['L1.log_brlem']    -0.6869      0.125     -5.512      0.000      -0.931      -0.443
# df['L2.Selic']        -0.0252      0.011     -2.255      0.024      -0.047      -0.003
# df['L2.log_ipca']     -1.1850      2.484     -0.477      0.633      -6.054       3.684
# df['L2.log_pimsa']    -0.4411      0.178     -2.477      0.013      -0.790      -0.092
# df['L2.log_fci']      -5.5078      2.081     -2.647      0.008      -9.587      -1.429
# df['L2.log_brlem']     0.2105      0.114      1.854      0.064      -0.012       0.433
# ==============================================================================
# Omnibus:                        3.981   Durbin-Watson:                   0.314
# Prob(Omnibus):                  0.137   Jarque-Bera (JB):                3.692
# Skew:                          -0.365   Prob(JB):                        0.158
# Kurtosis:                       3.088   Cond. No.                     2.55e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 34 lags and without small sample correction
# [2] The condition number is large, 2.55e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 34
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                     191.2
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           1.06e-82
# Time:                        17:00:02   Log-Likelihood:                 222.08
# No. Observations:                 163   AIC:                            -420.2
# Df Residuals:                     151   BIC:                            -383.0
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             33.7862      7.249      4.661      0.000      19.578      47.994
# df['Choque']           0.0140      0.076      0.185      0.853      -0.134       0.162
# df['L1.Selic']         0.0447      0.008      5.559      0.000       0.029       0.060
# df['L1.log_ipca']      0.3953      2.212      0.179      0.858      -3.940       4.731
# df['L1.log_pimsa']    -0.1559      0.111     -1.400      0.161      -0.374       0.062
# df['L1.log_fci']       1.4791      2.431      0.608      0.543      -3.286       6.244
# df['L1.log_brlem']    -0.5641      0.068     -8.332      0.000      -0.697      -0.431
# df['L2.Selic']        -0.0356      0.009     -3.829      0.000      -0.054      -0.017
# df['L2.log_ipca']     -0.9817      2.215     -0.443      0.658      -5.324       3.360
# df['L2.log_pimsa']    -0.3591      0.173     -2.078      0.038      -0.698      -0.020
# df['L2.log_fci']      -6.8329      2.239     -3.052      0.002     -11.220      -2.445
# df['L2.log_brlem']     0.0126      0.088      0.144      0.886      -0.159       0.184
# ==============================================================================
# Omnibus:                        4.930   Durbin-Watson:                   0.348
# Prob(Omnibus):                  0.085   Jarque-Bera (JB):                4.491
# Skew:                          -0.386   Prob(JB):                        0.106
# Kurtosis:                       3.254   Cond. No.                     2.56e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 35 lags and without small sample correction
# [2] The condition number is large, 2.56e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 35
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     171.8
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           4.28e-79
# Time:                        17:00:02   Log-Likelihood:                 225.32
# No. Observations:                 162   AIC:                            -426.6
# Df Residuals:                     150   BIC:                            -389.6
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             34.3472      7.272      4.723      0.000      20.095      48.599
# df['Choque']           0.0377      0.087      0.431      0.667      -0.134       0.209
# df['L1.Selic']         0.0547      0.013      4.155      0.000       0.029       0.081
# df['L1.log_ipca']      1.0712      2.398      0.447      0.655      -3.629       5.771
# df['L1.log_pimsa']    -0.1419      0.137     -1.035      0.301      -0.410       0.127
# df['L1.log_fci']      -0.7310      2.623     -0.279      0.780      -5.872       4.410
# df['L1.log_brlem']    -0.5953      0.110     -5.432      0.000      -0.810      -0.380
# df['L2.Selic']        -0.0460      0.012     -3.844      0.000      -0.069      -0.023
# df['L2.log_ipca']     -1.6959      2.422     -0.700      0.484      -6.443       3.051
# df['L2.log_pimsa']    -0.3664      0.180     -2.033      0.042      -0.720      -0.013
# df['L2.log_fci']      -4.6242      2.227     -2.076      0.038      -8.990      -0.259
# df['L2.log_brlem']    -0.0260      0.110     -0.237      0.813      -0.242       0.190
# ==============================================================================
# Omnibus:                        2.004   Durbin-Watson:                   0.436
# Prob(Omnibus):                  0.367   Jarque-Bera (JB):                1.757
# Skew:                          -0.254   Prob(JB):                        0.415
# Kurtosis:                       3.056   Cond. No.                     2.56e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 36 lags and without small sample correction
# [2] The condition number is large, 2.56e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 36
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.832
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     179.8
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           4.27e-80
# Time:                        17:00:02   Log-Likelihood:                 226.63
# No. Observations:                 161   AIC:                            -429.3
# Df Residuals:                     149   BIC:                            -392.3
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             34.8799      6.971      5.004      0.000      21.218      48.542
# df['Choque']           0.0170      0.071      0.239      0.811      -0.122       0.157
# df['L1.Selic']         0.0610      0.015      4.015      0.000       0.031       0.091
# df['L1.log_ipca']      1.9269      2.640      0.730      0.466      -3.248       7.102
# df['L1.log_pimsa']     0.0511      0.208      0.245      0.806      -0.357       0.459
# df['L1.log_fci']      -3.3535      2.710     -1.237      0.216      -8.665       1.958
# df['L1.log_brlem']    -0.6502      0.095     -6.810      0.000      -0.837      -0.463
# df['L2.Selic']        -0.0533      0.014     -3.757      0.000      -0.081      -0.025
# df['L2.log_ipca']     -2.5859      2.676     -0.966      0.334      -7.831       2.659
# df['L2.log_pimsa']    -0.5607      0.158     -3.552      0.000      -0.870      -0.251
# df['L2.log_fci']      -1.9999      2.236     -0.894      0.371      -6.382       2.382
# df['L2.log_brlem']    -0.0353      0.114     -0.308      0.758      -0.259       0.189
# ==============================================================================
# Omnibus:                        3.870   Durbin-Watson:                   0.440
# Prob(Omnibus):                  0.144   Jarque-Bera (JB):                3.392
# Skew:                          -0.300   Prob(JB):                        0.183
# Kurtosis:                       3.382   Cond. No.                     2.55e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 37 lags and without small sample correction
# [2] The condition number is large, 2.55e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 37
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           df['LP_lhs']   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     128.7
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           6.37e-70
# Time:                        17:00:02   Log-Likelihood:                 225.82
# No. Observations:                 160   AIC:                            -427.6
# Df Residuals:                     148   BIC:                            -390.7
# Df Model:                          11
# Covariance Type:                  HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             31.8722      6.612      4.820      0.000      18.913      44.831
# df['Choque']           0.0589      0.039      1.513      0.130      -0.017       0.135
# df['L1.Selic']         0.0647      0.016      3.959      0.000       0.033       0.097
# df['L1.log_ipca']      1.2525      2.688      0.466      0.641      -4.015       6.520
# df['L1.log_pimsa']    -0.0952      0.178     -0.535      0.592      -0.444       0.253
# df['L1.log_fci']      -3.2648      2.765     -1.181      0.238      -8.684       2.154
# df['L1.log_brlem']    -0.6573      0.071     -9.309      0.000      -0.796      -0.519
# df['L2.Selic']        -0.0573      0.014     -3.991      0.000      -0.085      -0.029
# df['L2.log_ipca']     -1.9433      2.726     -0.713      0.476      -7.286       3.399
# df['L2.log_pimsa']    -0.3129      0.184     -1.702      0.089      -0.673       0.047
# df['L2.log_fci']      -1.3923      2.038     -0.683      0.494      -5.386       2.601
# df['L2.log_brlem']    -0.1301      0.087     -1.503      0.133      -0.300       0.040
# ==============================================================================
# Omnibus:                        6.252   Durbin-Watson:                   0.509
# Prob(Omnibus):                  0.044   Jarque-Bera (JB):                5.877
# Skew:                          -0.408   Prob(JB):                       0.0529
# Kurtosis:                       3.463   Cond. No.                     2.55e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 38 lags and without small sample correction
# [2] The condition number is large, 2.55e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
