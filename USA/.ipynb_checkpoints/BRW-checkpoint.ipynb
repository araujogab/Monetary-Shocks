# %% [markdown]
# # BRW Estimation

# %% [markdown]
# Replication code of the BRW shock by Bu, Wu, and Rogers (2021).

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from linearmodels.iv import IV2SLS

maturity = 2
year = 2020
month = 12
monthname = "Dec"
MAR2020 = 0

# %% [markdown]
# ## 1. Calculating the difference of the 2-year Treasury series (DGS2)

# %% [markdown]
# Load the data and rename columns

# %%
data = pd.read_excel(r"C:\Users\Alysson\Documents\GitHub\Monetary-Shocks\USA\DGS2.xls")
data.rename(columns={"observation_date": "date"}, inplace=True)
data.sort_values(by='date', inplace=True)
data.replace(0, method='ffill', inplace=True)

# %% [markdown]
# Convert date to datetime format and create additional date-related columns

# %%
data["date"] = pd.to_datetime(data["date"])
data["year"] = data["date"].dt.year
data["month"] = data["date"].dt.month
data["day"] = data["date"].dt.day
data["mdate"] = data["date"].dt.to_period("M")

# %% [markdown]
# Filter data for the specified period (up to September 2019 - Cut-off date used for the estimation in the research paper.)

# %%
data = data[data["mdate"] <= pd.Period("2019-09")]
data = data[data["mdate"] >= pd.Period("1994-01")]

# %% [markdown]
# Calculate the difference of the series (dgs_d)

# %%
data["dgs_d"] = data["DGS" + str(maturity)] - data["DGS" + str(maturity)].shift(1)

# %% [markdown]
# Set "mdate" as the index and convert it to a time series

# %%
data.set_index("mdate", inplace=True)
data.index = pd.to_datetime(data.index.to_timestamp())

# %% [markdown]
# Drop unnecessary columns

# %%
data.drop(columns=["year", "month", "day"], inplace=True)
data.head()
# Out:
#                  date  DGS2  dgs_d
# mdate
# 1994-01-01 1994-01-03  4.30    NaN
# 1994-01-01 1994-01-04  4.29  -0.01
# 1994-01-01 1994-01-05  4.31   0.02
# 1994-01-01 1994-01-06  4.24  -0.07
# 1994-01-01 1994-01-07  4.09  -0.15

# %% [markdown]
# Save the resulting DataFrame to a new file

# %%
data.to_pickle("temp.pkl")

# %% [markdown]
# ## 2. Adding FOMC dates

# %% [markdown]
# Load the FOMC dates from the Excel file

# %%
fomc_dates = pd.read_excel("C:/Users/Alysson/Documents/GitHub/Monetary-Shocks/USA/FOMCdate.xlsx")
fomc_dates.rename(columns={"date": "FOMC_date"}, inplace=True)

# %% [markdown]
# Convert date to datetime format and create additional date-related columns

# %%
fomc_dates["FOMC_date"] = pd.to_datetime(fomc_dates["FOMC_date"])
fomc_dates["year"] = fomc_dates["FOMC_date"].dt.year
fomc_dates["month"] = fomc_dates["FOMC_date"].dt.month
fomc_dates["day"] = fomc_dates["FOMC_date"].dt.day
fomc_dates["mdate"] = fomc_dates["FOMC_date"].dt.to_period("M")

MAR2020 = 0

if MAR2020 == 0:
    fomc_dates = fomc_dates[~((fomc_dates["year"] == 2020) & (fomc_dates["month"] == 3) & (fomc_dates["day"] == 15))]

# %% [markdown]
# Drop unnecessary columns

# %%
fomc_dates.drop(columns=["year", "month", "day"], inplace=True)

# %% [markdown]
# Load the previous DataFrame "temp.dta"

# %%
temp_data = pd.read_pickle("temp.pkl")

# %% [markdown]
# Merge the two DataFrames on the 'date' column

# %%
merged_data = pd.merge(temp_data, fomc_dates, how="inner", left_on="date", right_on="FOMC_date")

# %% [markdown]
# Drop rows where 'q' is missing (denoted as NaN)

# %%
merged_data = merged_data.dropna(subset=["q"])

# %% [markdown]
# Replace missing values (NaN) in 'q' with 0

# %%
merged_data["q"].fillna(0, inplace=True)
merged_data.head()
# Out:
#         date  DGS2  dgs_d  FOMC_date  q    mdate
# 0 1994-02-04  4.42   0.14 1994-02-04  1  1994-02
# 1 1994-02-11  4.44  -0.01 1994-02-11  0  1994-02
# 2 1994-03-22  5.03  -0.06 1994-03-22  1  1994-03
# 3 1994-03-29  5.19   0.07 1994-03-29  0  1994-03
# 4 1994-05-17  5.88  -0.15 1994-05-17  1  1994-05

# %% [markdown]
# Save the merged DataFrame to a new file

# %%
merged_data.to_pickle("temp.pkl")

# %% [markdown]
# ## 3. Estimation

# %% [markdown]
# Load the data from "feds200628.csv"

# %%
yield_data = pd.read_csv(r"C:\Users\Alysson\Documents\GitHub\Monetary-Shocks\USA\feds200628.csv")

# %% [markdown]
# Convert 'date' column to datetime format and keeping only necessary columns

# %%
yield_data['date'] = pd.to_datetime(yield_data['Date'], format='%Y-%m-%d')
yield_data.sort_values(by='date', inplace=True)
yield_data.loc[:, 'SVENY01':'SVENY30'] = yield_data.loc[:, 'SVENY01':'SVENY30'].fillna(method='ffill')

# %%
yield_data['year'] = yield_data['date'].dt.year
yield_data['month'] = yield_data['date'].dt.month
yield_data['day'] = yield_data['date'].dt.day
yield_data['date'] = pd.to_datetime(yield_data[['year', 'month', 'day']])
yield_data['mdate'] = yield_data['date'].dt.to_period('M')
yield_data = yield_data[['date', 'mdate'] + [col for col in yield_data.columns if col.startswith('SVENY')]]
yield_data = yield_data[yield_data['mdate'] >= pd.Period('1994-01')]

# %% [markdown]
# Create a list for all maturities of the treasuries

# %% [markdown]
# Calculate differences for each maturity

# %%
list_maturities = [str(i).zfill(2) for i in range(1, 31)]

for num in list_maturities:
    col_name = f'SVENY{num}'
    yield_data[f'{col_name}_d'] = yield_data[col_name].diff()
selected_columns = yield_data.iloc[:, -30:]

# %% [markdown]
# Create aligned_dgs_d column

# %%
data_complete = merged_data.merge(yield_data, on=['date','mdate'], how='inner')
data_complete.head()
# Out:
#         date  DGS2  dgs_d  FOMC_date  q    mdate   SVENY01   SVENY02  \
# 0 1994-02-04  4.42   0.14 1994-02-04  1  1994-02  3.865749  4.369629
# 1 1994-02-11  4.44  -0.01 1994-02-11  0  1994-02  3.900780  4.405665
# 2 1994-03-22  5.03  -0.06 1994-03-22  1  1994-03  4.443199  5.001075
# 3 1994-03-29  5.19   0.07 1994-03-29  0  1994-03  4.526711  5.186564
# 4 1994-05-17  5.88  -0.15 1994-05-17  1  1994-05  5.301464  5.864555
#
#     SVENY03   SVENY04  ...  SVENY21_d  SVENY22_d  SVENY23_d  SVENY24_d  \
# 0  4.744739  5.047987  ...   0.035375   0.028441   0.022022   0.016079
# 1  4.795111  5.103778  ...  -0.032590  -0.032605  -0.032620  -0.032637
# 2  5.396750  5.697230  ...  -0.076686  -0.075292  -0.074018  -0.072847
# 3  5.626675  5.952448  ...   0.082017   0.081543   0.081109   0.080710
# 4  6.191343  6.429637  ...  -0.172195  -0.166615  -0.161111  -0.155718
#
#    SVENY25_d  SVENY26_d  SVENY27_d  SVENY28_d  SVENY29_d  SVENY30_d
# 0   0.010570   0.005457   0.000704  -0.003722  -0.007851  -0.011711
# 1  -0.032654  -0.032672  -0.032691  -0.032709  -0.032727  -0.032745
# 2  -0.071769  -0.070774  -0.069852  -0.068995  -0.068197  -0.067453
# 3   0.080344   0.080005   0.079691   0.079400   0.079129   0.078875
# 4  -0.150464  -0.145369  -0.140451  -0.135722  -0.131189  -0.126857
#
# [5 rows x 66 columns]

# %% [markdown]
# ### Step 1 - 2SLS

# %%
### Creating IV

mask_q0 = data_complete["q"] == 0
mask_q1 = data_complete["q"] == 1
data_complete["const"] = 1
data_complete["iv"] = data_complete[mask_q1]["dgs_d"]
data_complete.loc[mask_q0, "iv"] = -1 * data_complete.loc[mask_q0, "dgs_d"]

# %%
for num in list_maturities:
    col_name = f'SVENY{num}_d'
    model = IV2SLS(dependent=data_complete[col_name], endog=data_complete["dgs_d"], exog=data_complete[["const"]], instruments=data_complete["iv"])
    results = model.fit()
    data_complete[f"beta_hat{num}"]=results.params["dgs_d"]
    print(results)
data_complete.head()
# Out:
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY01_d   R-squared:                      0.8182
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.8178
# No. Observations:                 422   F-statistic:                    228.00
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0000
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0004     0.0010     0.4495     0.6531     -0.0015      0.0023
# dgs_d          0.8318     0.0551     15.100     0.0000      0.7238      0.9397
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY02_d   R-squared:                      0.9235
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.9234
# No. Observations:                 422   F-statistic:                    672.35
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0000
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0021     0.0008     2.7016     0.0069      0.0006      0.0037
# dgs_d          1.0080     0.0389     25.930     0.0000      0.9318      1.0842
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY03_d   R-squared:                      0.8777
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.8774
# No. Observations:                 422   F-statistic:                    227.30
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0000
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0025     0.0010     2.4717     0.0134      0.0005      0.0046
# dgs_d          1.0450     0.0693     15.076     0.0000      0.9091      1.1808
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY04_d   R-squared:                      0.8011
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.8007
# No. Observations:                 422   F-statistic:                    92.041
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0000
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0025     0.0013     1.8774     0.0605     -0.0001      0.0051
# dgs_d          1.0176     0.1061     9.5938     0.0000      0.8097      1.2255
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY05_d   R-squared:                      0.7240
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.7233
# No. Observations:                 422   F-statistic:                    48.800
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0000
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0023     0.0016     1.4820     0.1383     -0.0007      0.0054
# dgs_d          0.9623     0.1378     6.9857     0.0000      0.6923      1.2323
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY06_d   R-squared:                      0.6549
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.6540
# No. Observations:                 422   F-statistic:                    30.405
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0000
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0021     0.0017     1.2305     0.2185     -0.0013      0.0055
# dgs_d          0.8960     0.1625     5.5140     0.0000      0.5775      1.2145
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY07_d   R-squared:                      0.5952
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.5942
# No. Observations:                 422   F-statistic:                    21.053
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0000
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0020     0.0019     1.0621     0.2882     -0.0017      0.0056
# dgs_d          0.8271     0.1803     4.5883     0.0000      0.4738      1.1803
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY08_d   R-squared:                      0.5439
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.5428
# No. Observations:                 422   F-statistic:                    15.715
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0001
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0018     0.0019     0.9460     0.3441     -0.0020      0.0056
# dgs_d          0.7590     0.1915     3.9643     0.0001      0.3838      1.1343
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY09_d   R-squared:                      0.4998
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.4986
# No. Observations:                 422   F-statistic:                    12.402
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0004
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0017     0.0020     0.8648     0.3872     -0.0022      0.0057
# dgs_d          0.6940     0.1971     3.5216     0.0004      0.3078      1.0803
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY10_d   R-squared:                      0.4612
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.4599
# No. Observations:                 422   F-statistic:                    10.202
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0014
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0017     0.0021     0.8048     0.4209     -0.0024      0.0057
# dgs_d          0.6330     0.1982     3.1941     0.0014      0.2446      1.0214
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY11_d   R-squared:                      0.4268
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.4254
# No. Observations:                 422   F-statistic:                    8.6572
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0033
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0016     0.0021     0.7567     0.4493     -0.0025      0.0057
# dgs_d          0.5760     0.1958     2.9423     0.0033      0.1923      0.9597
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY12_d   R-squared:                      0.3956
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.3941
# No. Observations:                 422   F-statistic:                    7.5122
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0061
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0015     0.0021     0.7164     0.4737     -0.0026      0.0057
# dgs_d          0.5234     0.1910     2.7408     0.0061      0.1491      0.8977
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY13_d   R-squared:                      0.3667
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.3652
# No. Observations:                 422   F-statistic:                    6.6240
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0101
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0015     0.0021     0.6847     0.4935     -0.0027      0.0057
# dgs_d          0.4752     0.1846     2.5737     0.0101      0.1133      0.8371
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY14_d   R-squared:                      0.3398
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.3382
# No. Observations:                 422   F-statistic:                    5.8962
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0152
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0014     0.0022     0.6539     0.5132     -0.0028      0.0057
# dgs_d          0.4311     0.1775     2.4282     0.0152      0.0831      0.7791
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY15_d   R-squared:                      0.3142
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.3126
# No. Observations:                 422   F-statistic:                    5.2596
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0218
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0014     0.0022     0.6232     0.5331     -0.0029      0.0057
# dgs_d          0.3907     0.1704     2.2934     0.0218      0.0568      0.7247
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY16_d   R-squared:                      0.2900
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.2883
# No. Observations:                 422   F-statistic:                    4.6846
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0304
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0013     0.0022     0.5893     0.5556     -0.0030      0.0056
# dgs_d          0.3540     0.1636     2.1644     0.0304      0.0334      0.6746
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY17_d   R-squared:                      0.2673
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.2656
# No. Observations:                 422   F-statistic:                    4.1576
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0414
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0012     0.0022     0.5535     0.5799     -0.0031      0.0056
# dgs_d          0.3210     0.1574     2.0390     0.0414      0.0124      0.6295
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY18_d   R-squared:                      0.2460
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.2442
# No. Observations:                 422   F-statistic:                    3.6545
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0559
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0012     0.0022     0.5173     0.6049     -0.0032      0.0056
# dgs_d          0.2910     0.1522     1.9117     0.0559     -0.0073      0.5893
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY19_d   R-squared:                      0.2261
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.2242
# No. Observations:                 422   F-statistic:                    3.1899
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0741
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0011     0.0023     0.4762     0.6339     -0.0034      0.0055
# dgs_d          0.2641     0.1479     1.7860     0.0741     -0.0257      0.5539
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY20_d   R-squared:                      0.2076
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.2057
# No. Observations:                 422   F-statistic:                    2.7560
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.0969
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0010     0.0023     0.4339     0.6644     -0.0035      0.0054
# dgs_d          0.2400     0.1445     1.6601     0.0969     -0.0433      0.5233
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY21_d   R-squared:                      0.1908
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.1889
# No. Observations:                 422   F-statistic:                    2.3677
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.1239
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0009     0.0023     0.3887     0.6975     -0.0036      0.0054
# dgs_d          0.2187     0.1421     1.5387     0.1239     -0.0599      0.4972
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY22_d   R-squared:                      0.1753
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.1733
# No. Observations:                 422   F-statistic:                    2.0170
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.1556
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0008     0.0023     0.3425     0.7320     -0.0037      0.0053
# dgs_d          0.1997     0.1406     1.4202     0.1556     -0.0759      0.4752
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY23_d   R-squared:                      0.1610
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.1590
# No. Observations:                 422   F-statistic:                    1.7107
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.1909
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0007     0.0023     0.2948     0.7681     -0.0038      0.0052
# dgs_d          0.1829     0.1398     1.3080     0.1909     -0.0912      0.4569
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY24_d   R-squared:                      0.1481
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.1461
# No. Observations:                 422   F-statistic:                    1.4484
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.2288
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0006     0.0023     0.2450     0.8064     -0.0040      0.0051
# dgs_d          0.1682     0.1398     1.2035     0.2288     -0.1057      0.4422
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY25_d   R-squared:                      0.1363
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.1342
# No. Observations:                 422   F-statistic:                    1.2251
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.2684
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0005     0.0023     0.1946     0.8457     -0.0041      0.0050
# dgs_d          0.1554     0.1404     1.1068     0.2684     -0.1198      0.4306
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY26_d   R-squared:                      0.1256
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.1236
# No. Observations:                 422   F-statistic:                    1.0421
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.3073
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0003     0.0023     0.1436     0.8858     -0.0042      0.0049
# dgs_d          0.1446     0.1417     1.0208     0.3073     -0.1330      0.4223
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY27_d   R-squared:                      0.1159
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.1137
# No. Observations:                 422   F-statistic:                    0.8887
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.3458
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0002     0.0023     0.0945     0.9247     -0.0044      0.0048
# dgs_d          0.1353     0.1436     0.9427     0.3458     -0.1460      0.4167
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY28_d   R-squared:                      0.1070
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.1049
# No. Observations:                 422   F-statistic:                    0.7654
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.3816
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0001     0.0024     0.0459     0.9634     -0.0045      0.0047
# dgs_d          0.1278     0.1460     0.8749     0.3816     -0.1585      0.4140
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY29_d   R-squared:                      0.0987
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.0966
# No. Observations:                 422   F-statistic:                    0.6609
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.4163
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const      -2.554e-06     0.0024    -0.0011     0.9991     -0.0047      0.0047
# dgs_d          0.1213     0.1492     0.8129     0.4163     -0.1711      0.4136
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              SVENY30_d   R-squared:                      0.0913
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.0891
# No. Observations:                 422   F-statistic:                    0.5796
# Date:                Wed, Sep 06 2023   P-value (F-stat)                0.4465
# Time:                        08:12:42   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0001     0.0024    -0.0481     0.9616     -0.0049      0.0046
# dgs_d          0.1163     0.1528     0.7613     0.4465     -0.1831      0.4157
# ==============================================================================
#
# Endogenous: dgs_d
# Instruments: iv
# Robust Covariance (Heteroskedastic)
# Debiased: False
#         date  DGS2  dgs_d  FOMC_date  q    mdate   SVENY01   SVENY02  \
# 0 1994-02-04  4.42   0.14 1994-02-04  1  1994-02  3.865749  4.369629
# 1 1994-02-11  4.44  -0.01 1994-02-11  0  1994-02  3.900780  4.405665
# 2 1994-03-22  5.03  -0.06 1994-03-22  1  1994-03  4.443199  5.001075
# 3 1994-03-29  5.19   0.07 1994-03-29  0  1994-03  4.526711  5.186564
# 4 1994-05-17  5.88  -0.15 1994-05-17  1  1994-05  5.301464  5.864555
#
#     SVENY03   SVENY04  ...  beta_hat21  beta_hat22  beta_hat23  beta_hat24  \
# 0  4.744739  5.047987  ...    0.218667    0.199654    0.182882    0.168211
# 1  4.795111  5.103778  ...    0.218667    0.199654    0.182882    0.168211
# 2  5.396750  5.697230  ...    0.218667    0.199654    0.182882    0.168211
# 3  5.626675  5.952448  ...    0.218667    0.199654    0.182882    0.168211
# 4  6.191343  6.429637  ...    0.218667    0.199654    0.182882    0.168211
#
#    beta_hat25  beta_hat26  beta_hat27  beta_hat28  beta_hat29  beta_hat30
# 0    0.155421    0.144619     0.13534    0.127766     0.12125    0.116301
# 1    0.155421    0.144619     0.13534    0.127766     0.12125    0.116301
# 2    0.155421    0.144619     0.13534    0.127766     0.12125    0.116301
# 3    0.155421    0.144619     0.13534    0.127766     0.12125    0.116301
# 4    0.155421    0.144619     0.13534    0.127766     0.12125    0.116301
#
# [5 rows x 98 columns]

# %% [markdown]
# ### Step 2 - Fama and MacBeth

# %%
data_complete = data_complete.loc[~mask_q0]
maxt = len(data_complete)

aligned_dgs_d = []
for num in range(maxt):
    sveny_values = data_complete.iloc[num, data_complete.columns.get_loc("SVENY01_d"):data_complete.columns.get_loc("SVENY30_d") + 1].values.astype(float)
    beta_values = data_complete.iloc[num, data_complete.columns.get_loc("beta_hat01"):data_complete.columns.get_loc("beta_hat30") + 1].values.astype(float)

    # Adicionando uma constante à matriz independente (para o termo constante na regressão)
    X = sm.add_constant(beta_values)

    # Realizando a regressão usando o OLS do StatsModels
    model = sm.OLS(sveny_values, X)
    results = model.fit()

    # Imprimindo os coeficientes beta estimados
    aligned_dgs_d.append(results.params[1:])

data_complete["new_shock"]=aligned_dgs_d
data_complete["new_shock"] = data_complete["new_shock"].apply(lambda x: x[0])

# %%
data_complete
# Out:
#           date  DGS2  dgs_d  FOMC_date  q    mdate   SVENY01   SVENY02  \
# 0   1994-02-04  4.42   0.14 1994-02-04  1  1994-02  3.865749  4.369629
# 2   1994-03-22  5.03  -0.06 1994-03-22  1  1994-03  4.443199  5.001075
# 4   1994-05-17  5.88  -0.15 1994-05-17  1  1994-05  5.301464  5.864555
# 6   1994-07-06  6.11  -0.03 1994-07-06  1  1994-07  5.450049  6.058891
# 8   1994-08-16  6.21  -0.05 1994-08-16  1  1994-08  5.590755  6.139912
# ..         ...   ...    ...        ... ..      ...       ...       ...
# 412 2019-03-20  2.40  -0.06 2019-03-20  1  2019-03  2.467100  2.386700
# 414 2019-05-01  2.31   0.04 2019-05-01  1  2019-05  2.375600  2.302100
# 416 2019-06-19  1.74  -0.12 2019-06-19  1  2019-06  1.949800  1.760200
# 418 2019-07-31  1.89   0.04 2019-07-31  1  2019-07  2.034600  1.893800
# 420 2019-09-18  1.77   0.05 2019-09-18  1  2019-09  1.907400  1.795100
#
#       SVENY03   SVENY04  ...  beta_hat22  beta_hat23  beta_hat24  beta_hat25  \
# 0    4.744739  5.047987  ...    0.199654    0.182882    0.168211    0.155421
# 2    5.396750  5.697230  ...    0.199654    0.182882    0.168211    0.155421
# 4    6.191343  6.429637  ...    0.199654    0.182882    0.168211    0.155421
# 6    6.415837  6.670307  ...    0.199654    0.182882    0.168211    0.155421
# 8    6.433959  6.633408  ...    0.199654    0.182882    0.168211    0.155421
# ..        ...       ...  ...         ...         ...         ...         ...
# 412  2.351500  2.346900  ...    0.199654    0.182882    0.168211    0.155421
# 414  2.280500  2.290900  ...    0.199654    0.182882    0.168211    0.155421
# 416  1.717800  1.740600  ...    0.199654    0.182882    0.168211    0.155421
# 418  1.839700  1.831500  ...    0.199654    0.182882    0.168211    0.155421
# 420  1.735100  1.709100  ...    0.199654    0.182882    0.168211    0.155421
#
#      beta_hat26  beta_hat27  beta_hat28  beta_hat29  beta_hat30  new_shock
# 0      0.144619     0.13534    0.127766     0.12125    0.116301   0.169879
# 2      0.144619     0.13534    0.127766     0.12125    0.116301  -0.038950
# 4      0.144619     0.13534    0.127766     0.12125    0.116301  -0.025459
# 6      0.144619     0.13534    0.127766     0.12125    0.116301  -0.018402
# 8      0.144619     0.13534    0.127766     0.12125    0.116301   0.042428
# ..          ...         ...         ...         ...         ...        ...
# 412    0.144619     0.13534    0.127766     0.12125    0.116301  -0.035716
# 414    0.144619     0.13534    0.127766     0.12125    0.116301   0.063701
# 416    0.144619     0.13534    0.127766     0.12125    0.116301  -0.078279
# 418    0.144619     0.13534    0.127766     0.12125    0.116301   0.086887
# 420    0.144619     0.13534    0.127766     0.12125    0.116301   0.057713
#
# [211 rows x 99 columns]

# %% [markdown]
# ### Renormalization

# %%
renormalization = sm.OLS(data_complete["dgs_d"], data_complete["new_shock"])
results_renormalization = renormalization.fit()
beta_estimado = results_renormalization.params["new_shock"]
data_complete["BRW_daily"]=data_complete["new_shock"]*beta_estimado 
#print(results_renormalization.summary())

# %%
BRW_regression = sm.OLS(data_complete["dgs_d"], data_complete["BRW_daily"])
results_BRW_regression = BRW_regression.fit()
print(results_BRW_regression.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  dgs_d   R-squared (uncentered):                   0.470
# Model:                            OLS   Adj. R-squared (uncentered):              0.468
# Method:                 Least Squares   F-statistic:                              186.6
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):                    8.14e-31
# Time:                        08:13:52   Log-Likelihood:                          343.14
# No. Observations:                 211   AIC:                                     -684.3
# Df Residuals:                     210   BIC:                                     -680.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# BRW_daily      1.0000      0.073     13.659      0.000       0.856       1.144
# ==============================================================================
# Omnibus:                       15.206   Durbin-Watson:                   2.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.207
# Skew:                          -0.050   Prob(JB):                     1.53e-10
# Kurtosis:                       5.265   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Converter valores do tipo Period para datetime
mdate_values = data_complete["mdate"].dt.to_timestamp()
new_shock_values = data_complete["BRW_daily"]

# Criar um gráfico de linha
plt.figure(figsize=(15, 6))
plt.plot(mdate_values, new_shock_values)
plt.title("BRW")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
data_complete["BRW_daily"]
# Out:
# 0      0.111222
# 2     -0.025501
# 4     -0.016668
# 6     -0.012048
# 8      0.027778
#          ...
# 412   -0.023383
# 414    0.041705
# 416   -0.051250
# 418    0.056886
# 420    0.037785
# Name: BRW_daily, Length: 211, dtype: float64

# %%
# Definir a data de início e a data de término
start_date = pd.to_datetime("1994-01-01")
end_date = pd.to_datetime("2019-09-01")  # Especifique a data de término desejada

# Criar um intervalo de datas mensais até a data de término
date_range = pd.date_range(start=start_date, end=end_date, freq="M")

# Criar um DataFrame com a coluna de datas
data_monthly = pd.DataFrame({'mdate': date_range})

# Formatar as datas no estilo "1994-02"
data_monthly['mdate'] = data_monthly['mdate'].dt.strftime('%Y-%m')

# Imprimir as primeiras linhas do DataFrame
print(data_monthly.head())
# Out:
#      mdate
# 0  1994-01
# 1  1994-02
# 2  1994-03
# 3  1994-04
# 4  1994-05
